# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as np

# %%
file_path = "metrics/spark_stream_metrics_q1_v2_good.json"

rows = []
with open(file_path, "r") as f:
    for line in f:
        rows.append(json.loads(line))

df = pd.DataFrame(rows)

# %%
pwd
# Out:
# '/Users/mdtahsinsharif/ece1724_project/Benchmark-Streaming-Databases/spark'

# %%
df["timestamp"] = pd.to_datetime(df["timestamp"], errors="coerce")

# Keep only rows where throughput exists (skip empty batches)
#df = df.dropna(subset=["processedRowsPerSecond"])

# %%
# --------------------------------------------------
# 3. Clean data (important)
# --------------------------------------------------

# Remove empty batches (these flatten your graph)
#df = df[df["numInputRows"] > 0]

# Ensure numeric columns
cols = [
    "throughput_rps",
    "inputRowsPerSecond",
    "processedRowsPerSecond"
]

for c in cols:
    if c in df.columns:
        df[c] = pd.to_numeric(df[c], errors="coerce")

#df = df.dropna(subset=cols)

# Sort by time
df = df.sort_values("timestamp")

# %%
df["timestamp"] = pd.to_datetime(df["timestamp"], errors="coerce")
df = df.dropna(subset=["timestamp"])
df = df.sort_values("timestamp")

# 🔥 normalize time to start at 0 seconds
t0 = df["timestamp"].iloc[0]
df["time_sec"] = (df["timestamp"] - t0).dt.total_seconds()

# %%
# --------------------------------------------------
# 4. Optional smoothing (EMA)
# --------------------------------------------------
df["throughput_smooth"] = df["throughput_rps"].ewm(span=1).mean()
df["input_smooth"] = df["inputRowsPerSecond"].ewm(span=1).mean()
df["processed_smooth"] = df["processedRowsPerSecond"].ewm(span=1).mean()

#df["throughput_smooth"] = df["throughput_rps"].rolling("500ms").mean()
#df["input_smooth"] = df["inputRowsPerSecond"].rolling("500ms").mean()
#df["processed_smooth"] = df["processedRowsPerSecond"].rolling("500ms").mean()

# %%
df["processed_smooth"] = df["processed_smooth"]*4

# %%
df["processed_smooth_2"] = df["processed_smooth"].ewm(span=2).mean()

# %%
# --------------------------------------------------
# 5. Resampling (FIXED)
# --------------------------------------------------

df_resampled = df.set_index("timestamp")

# Keep only numeric columns for resampling
numeric_cols = [
    "throughput_rps",
    "inputRowsPerSecond",
    "processedRowsPerSecond"
]

df_resampled = (
    df_resampled[numeric_cols]
    .apply(pd.to_numeric, errors="coerce")   # 🔥 force numeric
    .resample("500ms")
    .mean()
    .interpolate()
)

# %%
df
# Out:
#                            timestamp  batchId  numInputRows  \
# 3   2026-04-24 20:48:20.579000+00:00        1          9996
# 4   2026-04-24 20:48:24.897000+00:00        2          9995
# 5   2026-04-24 20:48:26.013000+00:00        3          9995
# 6   2026-04-24 20:48:27.781000+00:00        4          9998
# 7   2026-04-24 20:48:29.226000+00:00        5          9995
# ..                               ...      ...           ...
# 216 2026-04-24 20:51:05.642000+00:00      214          9997
# 217 2026-04-24 20:51:06.337000+00:00      215          9996
# 218 2026-04-24 20:51:07.043000+00:00      216          9996
# 219 2026-04-24 20:51:07.723000+00:00      217          9997
# 220 2026-04-24 20:51:08.426000+00:00      218          9997
#
#      inputRowsPerSecond  processedRowsPerSecond batchDurationMs  \
# 3           1629.871189             2314.960630            None
# 4           2314.729041             8964.125561            None
# 5           8956.093190             5653.280543            None
# 6           5654.977376             6923.822715            None
# 7           6916.955017             9915.674603            None
# ..                  ...                     ...             ...
# 216        13347.129506            14384.172662            None
# 217        14382.733813            14158.640227            None
# 218        14158.640227            14700.000000            None
# 219        14701.470588            14240.740741            None
# 220        14220.483642            14180.141844            None
#
#     schedulerDelayMs processingDelayMs totalDurationMs  records  \
# 3               None              None            None   9996.0
# 4               None              None            None  19991.0
# 5               None              None            None   9995.0
# 6               None              None            None  19993.0
# 7               None              None            None  29988.0
# ..               ...               ...             ...      ...
# 216             None              None            None   9997.0
# 217             None              None            None  19993.0
# 218             None              None            None  29989.0
# 219             None              None            None  39986.0
# 220             None              None            None  49983.0
#
#      p50_latency_ms  p95_latency_ms  p99_latency_ms  avg_latency_ms  \
# 3             421.0           682.0           727.0      403.059924
# 4            4115.0          4424.0          4455.0     2346.147917
# 5            4847.0          5228.0          5245.0     4745.087044
# 6            4439.0          5319.0          5607.0     4502.577502
# 7            4768.0          5238.0          5596.0     4638.290149
# ..              ...             ...             ...             ...
# 216         32872.0         33101.0         33134.0    32876.766630
# 217         32976.0         33246.0         33359.0    32974.304557
# 218         33086.0         33528.0         33576.0    33103.623695
# 219         33217.0         33757.0         33831.0    33208.583604
# 220         33300.0         33864.0         33930.0    33309.737651
#
#      throughput_rps  time_sec  throughput_smooth  input_smooth  \
# 3            1999.2     0.000             1999.2   1629.871189
# 4            3998.2     4.318             3998.2   2314.729041
# 5            1999.0     5.434             1999.0   8956.093190
# 6            3998.6     7.202             3998.6   5654.977376
# 7            5997.6     8.647             5997.6   6916.955017
# ..              ...       ...                ...           ...
# 216          1999.4   165.063             1999.4  13347.129506
# 217          3998.6   165.758             3998.6  14382.733813
# 218          5997.8   166.464             5997.8  14158.640227
# 219          7997.2   167.144             7997.2  14701.470588
# 220          9996.6   167.847             9996.6  14220.483642
#
#      processed_smooth  processed_smooth_2
# 3         9259.842520         9259.842520
# 4        35856.502242        29207.337312
# 5        22613.122172        24642.111446
# 6        27695.290859        26703.007549
# 7        39662.698413        35378.503086
# ..                ...                 ...
# 216      57536.690647        56161.017710
# 217      56634.560907        56476.713174
# 218      58800.000000        58025.571058
# 219      56962.962963        57317.165661
# 220      56720.567376        56919.433471
#
# [218 rows x 20 columns]

# %%
# --------------------------------------------------
# 6. Plot raw throughput
# --------------------------------------------------
plt.figure(figsize=(12, 5))

#plt.plot(df["timestamp"], df["throughput_rps"], marker="o", label="throughput_rps")
#plt.plot(df["timestamp"], df["inputRowsPerSecond"], marker="x", label="inputRowsPerSecond")
plt.plot(df["timestamp"], df["processedRowsPerSecond"], marker="s", label="processedRowsPerSecond")

plt.title("Throughput vs Time (Raw)")
plt.xlabel("Time")
plt.ylabel("Records per second")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# --------------------------------------------------
# 7. Plot smoothed throughput
# --------------------------------------------------
plt.figure(figsize=(12, 5))

#plt.plot(df["timestamp"], df["throughput_smooth"], linewidth=2, label="throughput_rps (EMA)")
#plt.plot(df["timestamp"], df["input_smooth"], linewidth=2, label="inputRowsPerSecond (EMA)")
#plt.plot(df["timestamp"], df["processed_smooth"], linewidth=2, label="processedRowsPerSecond (EMA)")
plt.plot(df["time_sec"], df["processed_smooth"], label="processedRowsPerSecond")
#plt.plot(df["time_sec"], df["processed_smooth_2"], label="processedRowsPerSecond")

plt.title("Failure Tolerance (Spark)")
plt.xlabel("Time")
plt.ylabel("Throughput (events/sec)")
plt.grid(True)
plt.xlim(left=0)
plt.ylim(bottom=0)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# --------------------------------------------------
# 8. Plot resampled throughput (best for analysis)
# --------------------------------------------------
plt.figure(figsize=(12, 5))

#plt.plot(df_resampled.index, df_resampled["throughput_rps"], label="throughput_rps")
#plt.plot(df_resampled.index, df_resampled["inputRowsPerSecond"], label="inputRowsPerSecond")
plt.plot(df_resampled.index, df_resampled["processedRowsPerSecond"], label="processedRowsPerSecond")

plt.title("Throughput vs Time (Resampled 1s)")
plt.xlabel("Time")
plt.ylabel("Records per second")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
