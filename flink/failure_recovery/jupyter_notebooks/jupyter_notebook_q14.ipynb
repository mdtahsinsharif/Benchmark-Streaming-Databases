# %%
import sys
print(sys.executable)
# Out:
# /Users/mdtahsinsharif/anaconda3/envs/stream-metrics/bin/python

# %%
import os
import tarfile
import shutil
import glob
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# %%
# ===================== CONFIG =====================
query = "q14"
failure = "fails"
base_dir = Path("fails_flink")
output_dir = Path("analysis_output") / failure / query
window_seconds = 5
# ==================================================

# %%
output_dir.mkdir(parents=True, exist_ok=True)

print("[START] Analysis pipeline starting...")
print(f"Query: {query}")
print(f"Base dir: {base_dir}")
print(f"Output dir: {output_dir}")

pattern = f"nexmark_{failure}_10p_{query}_*.tar"
tar_files = list(base_dir.glob(pattern))

print(f"[INFO] Found {len(tar_files)} tar files")

if not tar_files:
    print(f"No tar files found for {query}")
    exit(1)

node_data = {}
# Out:
# [START] Analysis pipeline starting...
# Query: q14
# Base dir: fails_flink
# Output dir: analysis_output/fails/q14
# [INFO] Found 2 tar files

# %%
def compute_latency_summary(df):
    return {
        "avg": df["latency_ms"].mean(),
        "p50": df["latency_ms"].quantile(0.50),
        "p95": df["latency_ms"].quantile(0.95),
        "p99": df["latency_ms"].quantile(0.99),
    }

# %%
def parse_part_file(pf):
    rows = []
    bad = 0

    print(f"[FILE] Processing: {os.path.basename(pf)}")

    max_errors_to_show = 5
    error_count = 0

    with open(pf, "r", errors="ignore") as f:
        for line_num, line in enumerate(f, 1):

            parts = line.rstrip("\n").split(",", 7)

            # Q10 expects at least 8 fields
            if len(parts) < 8:
                bad += 1
                if error_count < max_errors_to_show:
                    print(f"[WARN] Line {line_num}: insufficient columns -> {line.strip()}")
                    error_count += 1
                continue

            try:
                auction = parts[0]
                bidder = parts[1]
                bidder2 = parts[2]
                timeofday = parts[3]
                event_time = parts[4].strip('"')
                processed_time = parts[5].strip('"')
                extra = parts[6]
                booleannumber = parts[7]

                rows.append({
                    "auction": int(auction),
                    "bidder": int(bidder),
                    "bidder2": float(bidder2),
                    "timeofday": str(timeofday),
                    "event_time": event_time,
                    "processed_time": processed_time,
                    "extra": extra,
                    "booleannumber": int(booleannumber)
                })

            except Exception as e:
                bad += 1
                if error_count < max_errors_to_show:
                    print(f"[ERROR] Line {line_num}: {e}")
                    print(f"        data: {line.strip()}")
                    error_count += 1

    print(f"    -> parsed rows: {len(rows)} | bad rows: {bad}")
    return pd.DataFrame(rows)

# %%
# ===================== MAIN LOOP =====================
for tar_path in tar_files:
    tar_name = tar_path.stem
    node = tar_name.split("_")[-1]

    print("\n========================================")
    print(f"[TAR] Processing: {tar_name}")
    print(f"[NODE] Detected node: {node}")

    extract_root = base_dir / f"extracted_{tar_name}"
    temp_extract = base_dir / "_tmp_extract"

    flink_path = extract_root / "flink" / "nexmark" / query

    # -------- Extraction --------
    if extract_root.exists() and flink_path.exists():
        print(f"[SKIP] Already extracted: {extract_root}")
    else:
        if extract_root.exists():
            print("[CLEAN] Removing old extracted folder")
            shutil.rmtree(extract_root)

        if temp_extract.exists():
            shutil.rmtree(temp_extract)

        temp_extract.mkdir(parents=True, exist_ok=True)

        print(f"[EXTRACT] Extracting {tar_path}")
        with tarfile.open(tar_path) as tar:
            tar.extractall(path=temp_extract)

        print(f"[MOVE] Moving to {extract_root}")
        extract_root.mkdir(parents=True, exist_ok=True)

        extracted_items = list(temp_extract.iterdir())

        if len(extracted_items) == 1 and extracted_items[0].is_dir():
            shutil.move(str(extracted_items[0]), str(extract_root))
        else:
            for item in extracted_items:
                shutil.move(str(item), str(extract_root))

        shutil.rmtree(temp_extract)

    # -------- Data path --------
    data_path = extract_root / "mnt" / "nfs" / "flink" / "nexmark" / query
    print(f"[DATA] Looking in: {data_path}")

    #part_files = sorted(glob.glob(str(data_path / "part-*")))
    part_files = sorted(
        glob.glob(str(data_path / "**" / "part-*"), recursive=True)
    )
    print(f"[INFO] Found {len(part_files)} part files")

    if not part_files:
        print(f"[WARN] No part files for {node}")
        continue

    # -------- Load files --------
    dfs = []

    for pf in part_files:
        df_part = parse_part_file(pf)
        if not df_part.empty:
            dfs.append(df_part)

    if not dfs:
        print(f"[ERROR] No usable data for {node}")
        continue

    print(f"[MERGE] Concatenating {len(dfs)} dataframes...")
    df = pd.concat(dfs, ignore_index=True)
    print(f"[INFO] Total rows: {len(df)}")

    # -------- Clean timestamps --------
    print("[CLEAN] Converting timestamps...")
    df["event_time"] = pd.to_datetime(df["event_time"], errors="coerce")
    df["processed_time"] = pd.to_datetime(df["processed_time"], errors="coerce")

    bad_rows = df["event_time"].isna() | df["processed_time"].isna()
    print(f"[CLEAN] Dropping bad rows: {bad_rows.sum()}")

    df = df[~bad_rows]

    # -------- Latency --------
    print("[CALC] Computing latency...")
    df["processed_time"] = df["processed_time"] + pd.Timedelta(hours=4)
    
    df["latency_ms"] = (
        (df["processed_time"] - df["event_time"])
        .dt.total_seconds() * 1000
    )

    print("[SORT] Sorting by processed_time...")
    df = df.sort_values("processed_time").set_index("processed_time")

    node_data[node] = df
    print(f"[DONE] Node {node} ready")
    
    print("\n================ LATENCY SUMMARY ================\n")

    global_df = []

    for node, df in node_data.items():
        stats = compute_latency_summary(df)

        print(f"[{node}]")
        print(f"  Avg latency : {stats['avg']:.2f} ms")
        print(f"  P50 latency : {stats['p50']:.2f} ms")
        print(f"  P95 latency : {stats['p95']:.2f} ms")
        print(f"  P99 latency : {stats['p99']:.2f} ms")
        print()
# Out:
# ========================================
# [TAR] Processing: nexmark_fails_10p_q14_n1
# [NODE] Detected node: n1
# [CLEAN] Removing old extracted folder
# [EXTRACT] Extracting fails_flink/nexmark_fails_10p_q14_n1.tar
# [MOVE] Moving to fails_flink/extracted_nexmark_fails_10p_q14_n1
# [DATA] Looking in: fails_flink/extracted_nexmark_fails_10p_q14_n1/mnt/nfs/flink/nexmark/q14
# [INFO] Found 40 part files
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-1-0
#     -> parsed rows: 384296 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-1-1
#     -> parsed rows: 852425 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-1-2
#     -> parsed rows: 852540 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-1-3
#     -> parsed rows: 852425 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-1-4
#     -> parsed rows: 852555 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-1-5
#     -> parsed rows: 852519 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-1-6
#     -> parsed rows: 769743 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-2-0
#     -> parsed rows: 426227 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-2-1
#     -> parsed rows: 874467 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-2-2
#     -> parsed rows: 869090 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-2-3
#     -> parsed rows: 869023 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-2-4
#     -> parsed rows: 869056 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-2-5
#     -> parsed rows: 866193 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-2-6
#     -> parsed rows: 863509 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-2-7
#     -> parsed rows: 320466 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-4-0
#     -> parsed rows: 458851 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-4-1
#     -> parsed rows: 847117 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-4-2
#     -> parsed rows: 847073 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-4-3
#     -> parsed rows: 847170 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-4-4
#     -> parsed rows: 847177 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-4-5
#     -> parsed rows: 847151 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-4-6
#     -> parsed rows: 847139 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-4-7
#     -> parsed rows: 847136 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-4-8
#     -> parsed rows: 90790 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-5-0
#     -> parsed rows: 397346 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-5-1
#     -> parsed rows: 847195 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-5-2
#     -> parsed rows: 847054 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-5-3
#     -> parsed rows: 847033 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-5-4
#     -> parsed rows: 847088 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-5-5
#     -> parsed rows: 847093 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-5-6
#     -> parsed rows: 847160 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-5-7
#     -> parsed rows: 158317 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-9-0
#     -> parsed rows: 423640 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-9-1
#     -> parsed rows: 847025 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-9-2
#     -> parsed rows: 847229 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-9-3
#     -> parsed rows: 847167 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-9-4
#     -> parsed rows: 847086 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-9-5
#     -> parsed rows: 847145 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-9-6
#     -> parsed rows: 847103 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-9-7
#     -> parsed rows: 707417 | bad rows: 0
# [MERGE] Concatenating 40 dataframes...
# [INFO] Total rows: 29706236
# [CLEAN] Converting timestamps...
# [CLEAN] Dropping bad rows: 58897
# [CALC] Computing latency...
# [SORT] Sorting by processed_time...
# [DONE] Node n1 ready
#
# ================ LATENCY SUMMARY ================
#
# [n1]
#   Avg latency : 234882.64 ms
#   P50 latency : 234534.00 ms
#   P95 latency : 271512.00 ms
#   P99 latency : 279575.00 ms
#
#
# ========================================
# [TAR] Processing: nexmark_fails_10p_q14_n0
# [NODE] Detected node: n0
# [CLEAN] Removing old extracted folder
# [EXTRACT] Extracting fails_flink/nexmark_fails_10p_q14_n0.tar
# [MOVE] Moving to fails_flink/extracted_nexmark_fails_10p_q14_n0
# [DATA] Looking in: fails_flink/extracted_nexmark_fails_10p_q14_n0/mnt/nfs/flink/nexmark/q14
# [INFO] Found 41 part files
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-0-0
#     -> parsed rows: 412182 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-0-1
#     -> parsed rows: 847121 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-0-2
#     -> parsed rows: 847180 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-0-3
#     -> parsed rows: 847089 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-0-4
#     -> parsed rows: 847154 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-0-5
#     -> parsed rows: 847172 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-0-6
#     -> parsed rows: 847118 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-0-7
#     -> parsed rows: 797742 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-3-0
#     -> parsed rows: 386851 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-3-1
#     -> parsed rows: 847019 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-3-2
#     -> parsed rows: 847064 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-3-3
#     -> parsed rows: 847082 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-3-4
#     -> parsed rows: 847142 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-3-5
#     -> parsed rows: 847100 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-3-6
#     -> parsed rows: 847195 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-3-7
#     -> parsed rows: 847070 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-3-8
#     -> parsed rows: 241818 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-6-0
#     -> parsed rows: 374530 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-6-1
#     -> parsed rows: 847183 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-6-2
#     -> parsed rows: 847123 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-6-3
#     -> parsed rows: 847057 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-6-4
#     -> parsed rows: 847159 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-6-5
#     -> parsed rows: 847140 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-6-6
#     -> parsed rows: 847105 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-6-7
#     -> parsed rows: 1 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-7-0
#     -> parsed rows: 423795 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-7-1
#     -> parsed rows: 841792 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-7-2
#     -> parsed rows: 841848 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-7-3
#     -> parsed rows: 841850 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-7-4
#     -> parsed rows: 841762 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-7-5
#     -> parsed rows: 841735 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-7-6
#     -> parsed rows: 841822 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-7-7
#     -> parsed rows: 609020 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-8-0
#     -> parsed rows: 454765 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-8-1
#     -> parsed rows: 852486 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-8-2
#     -> parsed rows: 852610 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-8-3
#     -> parsed rows: 852447 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-8-4
#     -> parsed rows: 852430 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-8-5
#     -> parsed rows: 852407 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-8-6
#     -> parsed rows: 852416 | bad rows: 0
# [FILE] Processing: part-4c7abf97-66e4-480a-87a5-75686b541a49-8-7
#     -> parsed rows: 812490 | bad rows: 0
# [MERGE] Concatenating 41 dataframes...
# [INFO] Total rows: 30774072
# [CLEAN] Converting timestamps...
# [CLEAN] Dropping bad rows: 60440
# [CALC] Computing latency...
# [SORT] Sorting by processed_time...
# [DONE] Node n0 ready
#
# ================ LATENCY SUMMARY ================
#
# [n1]
#   Avg latency : 234882.64 ms
#   P50 latency : 234534.00 ms
#   P95 latency : 271512.00 ms
#   P99 latency : 279575.00 ms
#
# [n0]
#   Avg latency : 233381.92 ms
#   P50 latency : 233580.00 ms
#   P95 latency : 266442.00 ms
#   P99 latency : 278352.00 ms

# %%
# ===================== ANALYSIS =====================
def smooth(series, w=5):
    return series.rolling(w, min_periods=1).mean()

def compute_latency(df):
    r = df["latency_ms"].resample(f"{window_seconds}s")
    return pd.DataFrame({
        "p50": r.quantile(0.5),
        "p95": r.quantile(0.95),
        "p99": r.quantile(0.99),
    })

def compute_throughput(df):
    return df["auction"].resample(f"{window_seconds}s").size()

def detect_failures(tp):
    gaps = []
    start = None

    for ts, v in tp.items():
        if v == 0 and start is None:
            start = ts
        elif v > 0 and start is not None:
            gaps.append((start, ts))
            start = None

    return gaps

# %%
# ===================== PLOTTING =====================
print("[PLOT] Latency plot...")
plt.figure()

node_colors = {"n0": "blue", "n1": "orange"}
all_failures = []
# Out:
# [PLOT] Latency plot...

# %%
for node, df in node_data.items():
    lat = compute_latency(df)

    plt.plot(smooth(lat["p50"]), label=f"{node} p50", color=node_colors.get(node))
    plt.plot(smooth(lat["p95"]), linestyle="--", label=f"{node} p95", color=node_colors.get(node))
    plt.plot(smooth(lat["p99"]), linestyle=":", label=f"{node} p99", color=node_colors.get(node))

plt.title(f"Latency ({query})")
plt.xlabel("Time")
plt.ylabel("ms")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig(output_dir / f"latency_{query}.png")
plt.close()

print("[PLOT] Throughput plot...")
plt.figure()
# Out:
# [PLOT] Throughput plot...

# %%
for node, df in node_data.items():
    tp = compute_throughput(df)
    tp_s = smooth(tp)

    plt.plot(tp_s, label=node, color=node_colors.get(node))

    gaps = detect_failures(tp)
    for start, end in gaps:
        all_failures.append((start, end, node))

for start, end, node in all_failures:
    plt.axvspan(start, end, alpha=0.15, color=node_colors.get(node))
    mid = start + (end - start) / 2
    plt.text(mid, plt.ylim()[1] * 0.8, f"{node}", rotation=90, ha="center")

# %%
plt.title(f"Throughput ({query})")
plt.xlabel("Time")
plt.ylabel("events/sec")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig(output_dir / f"throughput_{query}.png")
plt.close()

print("[COMPLETE] Done. Outputs in:", output_dir)
# Out:
# [COMPLETE] Done. Outputs in: analysis_output/fails/q14
# /var/folders/q5/_vyqqcz16vg3sg5pn1mmprcw0000gn/T/ipykernel_50261/3772911770.py:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
df.head(2)
# Out:
#                            auction    bidder      bidder2  timeofday  \
# processed_time
# 2026-04-12 04:37:51.868  108000922  36002001  1259575.784  nightTime
# 2026-04-12 04:37:51.870  108001000  36002001  5910484.352  nightTime
#
#                                      event_time  \
# processed_time
# 2026-04-12 04:37:51.868 2026-04-12 04:34:37.096
# 2026-04-12 04:37:51.870 2026-04-12 04:34:37.096
#
#                                                                      extra  \
# processed_time
# 2026-04-12 04:37:51.868  WOavloghLQWORRWK\JH_OVWPZ\wuftjsxnwolifagfnviu...
# 2026-04-12 04:37:51.870  _OVwzxhnaTMK`OR`IHMLUlwxkpoalzhssQWO^W\aLHRVQY...
#
#                          booleannumber  latency_ms
# processed_time
# 2026-04-12 04:37:51.868              0    194772.0
# 2026-04-12 04:37:51.870              1    194774.0
