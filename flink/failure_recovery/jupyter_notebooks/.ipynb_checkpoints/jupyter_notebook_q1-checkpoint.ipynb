# %%
import sys
print(sys.executable)
# Out:
# /Users/mdtahsinsharif/anaconda3/envs/stream-metrics/bin/python

# %%
import os
import tarfile
import shutil
import glob
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# %%
# ===================== CONFIG =====================
query = "q1"
failure = "fails"
base_dir = Path(failure + "_flink")
output_dir = Path("analysis_output") / failure / query
window_seconds = 5
# ==================================================

# %%
output_dir.mkdir(parents=True, exist_ok=True)

print("[START] Analysis pipeline starting...")
print(f"Query: {query}")
print(f"Base dir: {base_dir}")
print(f"Output dir: {output_dir}")

pattern = f"nexmark_{failure}_10p_{query}_*.tar"
tar_files = list(base_dir.glob(pattern))

print(f"[INFO] Found {len(tar_files)} tar files")

if not tar_files:
    print(f"No tar files found for {query}")
    exit(1)

node_data = {}
# Out:
# [START] Analysis pipeline starting...
# Query: q1
# Base dir: fails_flink
# Output dir: analysis_output/fails/q1
# [INFO] Found 2 tar files

# %%
def compute_latency_summary(df):
    return {
        "avg": df["latency_ms"].mean(),
        "p50": df["latency_ms"].quantile(0.50),
        "p95": df["latency_ms"].quantile(0.95),
        "p99": df["latency_ms"].quantile(0.99),
    }

# %%
def parse_part_file(pf):
    rows = []
    bad = 0

    print(f"[FILE] Processing: {os.path.basename(pf)}")
    max_errors_to_show = 5
    error_count = 0
    with open(pf, "r", errors="ignore") as f:
        for line_num, line in enumerate(f, 1):
            parts = line.rstrip("\n").split(",", 5)

            if len(parts) < 6:
                bad += 1
                print(f"[WARN] Line {line_num}: insufficient columns -> {line.strip()}")
                continue

            auction, bidder, price, event_time, processed_time, extra= parts

            try:
                rows.append({
                    "auction": int(auction),
                    "bidder": int(auction),
                    "price": float(price),
                    "event_time": event_time,
                    "processed_time": processed_time,
                    "extra": extra
                })

            except Exception as e:
                bad += 1
                if error_count < max_errors_to_show:
                    print(f"[ERROR] Line {line_num}: {e}")
                    print(f"        data: {line.strip()}")
                    error_count += 1

    print(f"    -> parsed rows: {len(rows)} | bad rows: {bad}")
    return pd.DataFrame(rows)

# %%
# ===================== MAIN LOOP =====================
for tar_path in tar_files:
    tar_name = tar_path.stem
    node = tar_name.split("_")[-1]

    print("\n========================================")
    print(f"[TAR] Processing: {tar_name}")
    print(f"[NODE] Detected node: {node}")

    extract_root = base_dir / f"extracted_{tar_name}"
    temp_extract = base_dir / "_tmp_extract"

    flink_path = extract_root / "flink" / "nexmark" / query

    # -------- Extraction --------
    if extract_root.exists() and flink_path.exists():
        print(f"[SKIP] Already extracted: {extract_root}")
    else:
        if extract_root.exists():
            print("[CLEAN] Removing old extracted folder")
            shutil.rmtree(extract_root)

        if temp_extract.exists():
            shutil.rmtree(temp_extract)

        temp_extract.mkdir(parents=True, exist_ok=True)

        print(f"[EXTRACT] Extracting {tar_path}")
        with tarfile.open(tar_path) as tar:
            tar.extractall(path=temp_extract)

        print(f"[MOVE] Moving to {extract_root}")
        extract_root.mkdir(parents=True, exist_ok=True)

        extracted_items = list(temp_extract.iterdir())

        if len(extracted_items) == 1 and extracted_items[0].is_dir():
            shutil.move(str(extracted_items[0]), str(extract_root))
        else:
            for item in extracted_items:
                shutil.move(str(item), str(extract_root))

        shutil.rmtree(temp_extract)

    # -------- Data path --------
    data_path = extract_root / "mnt" / "nfs" / "flink" / "nexmark" / query
    print(f"[DATA] Looking in: {data_path}")

    part_files = sorted(glob.glob(str(data_path / "part-*")))
    print(f"[INFO] Found {len(part_files)} part files")

    if not part_files:
        print(f"[WARN] No part files for {node}")
        continue

    # -------- Load files --------
    dfs = []

    for pf in part_files:
        df_part = parse_part_file(pf)
        if not df_part.empty:
            dfs.append(df_part)

    if not dfs:
        print(f"[ERROR] No usable data for {node}")
        continue

    print(f"[MERGE] Concatenating {len(dfs)} dataframes...")
    df = pd.concat(dfs, ignore_index=True)
    print(f"[INFO] Total rows: {len(df)}")

    # -------- Clean timestamps --------
    print("[CLEAN] Converting timestamps...")
    df["event_time"] = pd.to_datetime(df["event_time"], errors="coerce")
    df["processed_time"] = pd.to_datetime(df["processed_time"], errors="coerce")

    bad_rows = df["event_time"].isna() | df["processed_time"].isna()
    print(f"[CLEAN] Dropping bad rows: {bad_rows.sum()}")

    df = df[~bad_rows]

    # -------- Latency --------
    print("[CALC] Computing latency...")
    df["processed_time"] = df["processed_time"] + pd.Timedelta(hours=4)
    
    df["latency_ms"] = (
        (df["processed_time"] - df["event_time"])
        .dt.total_seconds() * 1000
    )

    print("[SORT] Sorting by processed_time...")
    df = df.sort_values("processed_time").set_index("processed_time")

    node_data[node] = df
    print(f"[DONE] Node {node} ready")
    
    print("\n================ LATENCY SUMMARY ================\n")

    global_df = []

    for node, df in node_data.items():
        stats = compute_latency_summary(df)

        print(f"[{node}]")
        print(f"  Avg latency : {stats['avg']:.2f} ms")
        print(f"  P50 latency : {stats['p50']:.2f} ms")
        print(f"  P95 latency : {stats['p95']:.2f} ms")
        print(f"  P99 latency : {stats['p99']:.2f} ms")
        print()
# Out:
# ========================================
# [TAR] Processing: nexmark_fails_10p_q1_n1
# [NODE] Detected node: n1
# [CLEAN] Removing old extracted folder
# [EXTRACT] Extracting fails_flink/nexmark_fails_10p_q1_n1.tar
# [MOVE] Moving to fails_flink/extracted_nexmark_fails_10p_q1_n1
# [DATA] Looking in: fails_flink/extracted_nexmark_fails_10p_q1_n1/mnt/nfs/flink/nexmark/q1
# [INFO] Found 149 part files
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-0-0
#     -> parsed rows: 928935 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-0-1
#     -> parsed rows: 928965 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-0-10
#     -> parsed rows: 928990 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-0-11
#     -> parsed rows: 488335 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-0-12
#     -> parsed rows: 928861 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-0-13
#     -> parsed rows: 928930 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-0-14
#     -> parsed rows: 929036 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-0-15
#     -> parsed rows: 928879 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-0-16
#     -> parsed rows: 928991 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-0-17
#     -> parsed rows: 928854 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-0-18
#     -> parsed rows: 928906 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-0-19
#     -> parsed rows: 928935 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-0-2
#     -> parsed rows: 928913 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-0-20
#     -> parsed rows: 928972 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-0-21
#     -> parsed rows: 928867 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-0-22
#     -> parsed rows: 928969 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-0-23
#     -> parsed rows: 928956 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-0-24
#     -> parsed rows: 446810 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-0-3
#     -> parsed rows: 928871 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-0-4
#     -> parsed rows: 928977 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-0-5
#     -> parsed rows: 928864 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-0-6
#     -> parsed rows: 929036 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-0-7
#     -> parsed rows: 758322 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-0-9
#     -> parsed rows: 928930 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-1-0
#     -> parsed rows: 922536 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-1-1
#     -> parsed rows: 922473 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-1-10
#     -> parsed rows: 922559 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-1-11
#     -> parsed rows: 142624 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-1-12
#     -> parsed rows: 922606 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-1-13
#     -> parsed rows: 922607 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-1-14
#     -> parsed rows: 922549 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-1-15
#     -> parsed rows: 922628 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-1-16
#     -> parsed rows: 922524 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-1-17
#     -> parsed rows: 922522 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-1-18
#     -> parsed rows: 922642 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-1-19
#     -> parsed rows: 922534 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-1-2
#     -> parsed rows: 922636 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-1-20
#     -> parsed rows: 922607 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-1-21
#     -> parsed rows: 922528 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-1-22
#     -> parsed rows: 922558 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-1-23
#     -> parsed rows: 223776 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-1-3
#     -> parsed rows: 922530 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-1-4
#     -> parsed rows: 922478 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-1-5
#     -> parsed rows: 922520 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-1-6
#     -> parsed rows: 922502 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-1-7
#     -> parsed rows: 324352 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-1-9
#     -> parsed rows: 922535 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-3-0
#     -> parsed rows: 928863 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-3-1
#     -> parsed rows: 928955 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-3-10
#     -> parsed rows: 928907 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-3-11
#     -> parsed rows: 151036 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-3-12
#     -> parsed rows: 929015 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-3-13
#     -> parsed rows: 928865 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-3-14
#     -> parsed rows: 928985 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-3-15
#     -> parsed rows: 928968 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-3-16
#     -> parsed rows: 928927 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-3-17
#     -> parsed rows: 928875 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-3-18
#     -> parsed rows: 928986 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-3-19
#     -> parsed rows: 928952 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-3-2
#     -> parsed rows: 928952 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-3-20
#     -> parsed rows: 928855 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-3-21
#     -> parsed rows: 928946 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-3-22
#     -> parsed rows: 928860 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-3-23
#     -> parsed rows: 928868 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-3-24
#     -> parsed rows: 12847 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-3-3
#     -> parsed rows: 928975 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-3-4
#     -> parsed rows: 928876 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-3-5
#     -> parsed rows: 928922 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-3-6
#     -> parsed rows: 928892 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-3-7
#     -> parsed rows: 726216 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-3-9
#     -> parsed rows: 928965 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-4-0
#     -> parsed rows: 928892 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-4-1
#     -> parsed rows: 928916 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-4-2
#     -> parsed rows: 928863 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-4-3
#     -> parsed rows: 928907 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-4-4
#     -> parsed rows: 929074 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-4-5
#     -> parsed rows: 928946 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-4-6
#     -> parsed rows: 928915 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-4-7
#     -> parsed rows: 296634 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-6-0
#     -> parsed rows: 928888 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-6-1
#     -> parsed rows: 928940 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-6-10
#     -> parsed rows: 928933 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-6-11
#     -> parsed rows: 209655 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-6-12
#     -> parsed rows: 928813 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-6-13
#     -> parsed rows: 928941 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-6-14
#     -> parsed rows: 928984 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-6-15
#     -> parsed rows: 928909 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-6-16
#     -> parsed rows: 928933 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-6-17
#     -> parsed rows: 928948 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-6-18
#     -> parsed rows: 928907 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-6-19
#     -> parsed rows: 928890 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-6-2
#     -> parsed rows: 928948 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-6-20
#     -> parsed rows: 929083 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-6-21
#     -> parsed rows: 928935 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-6-22
#     -> parsed rows: 928897 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-6-23
#     -> parsed rows: 928941 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-6-24
#     -> parsed rows: 314169 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-6-3
#     -> parsed rows: 928882 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-6-4
#     -> parsed rows: 928934 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-6-5
#     -> parsed rows: 928859 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-6-6
#     -> parsed rows: 928864 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-6-7
#     -> parsed rows: 599187 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-6-9
#     -> parsed rows: 928796 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-8-0
#     -> parsed rows: 928963 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-8-1
#     -> parsed rows: 928837 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-8-10
#     -> parsed rows: 928898 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-8-11
#     -> parsed rows: 149534 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-8-12
#     -> parsed rows: 928995 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-8-13
#     -> parsed rows: 928847 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-8-14
#     -> parsed rows: 929008 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-8-15
#     -> parsed rows: 928936 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-8-16
#     -> parsed rows: 928962 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-8-17
#     -> parsed rows: 928918 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-8-18
#     -> parsed rows: 928962 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-8-19
#     -> parsed rows: 928976 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-8-2
#     -> parsed rows: 928878 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-8-20
#     -> parsed rows: 928985 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-8-21
#     -> parsed rows: 928995 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-8-22
#     -> parsed rows: 928953 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-8-23
#     -> parsed rows: 300675 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-8-3
#     -> parsed rows: 928911 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-8-4
#     -> parsed rows: 928977 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-8-5
#     -> parsed rows: 928920 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-8-6
#     -> parsed rows: 928965 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-8-7
#     -> parsed rows: 711463 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-8-9
#     -> parsed rows: 928919 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-9-0
#     -> parsed rows: 935355 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-9-1
#     -> parsed rows: 935411 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-9-10
#     -> parsed rows: 935381 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-9-11
#     -> parsed rows: 144268 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-9-12
#     -> parsed rows: 935363 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-9-13
#     -> parsed rows: 935467 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-9-14
#     -> parsed rows: 935438 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-9-15
#     -> parsed rows: 935324 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-9-16
#     -> parsed rows: 935474 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-9-17
#     -> parsed rows: 935471 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-9-18
#     -> parsed rows: 935410 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-9-19
#     -> parsed rows: 935476 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-9-2
#     -> parsed rows: 935407 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-9-20
#     -> parsed rows: 935371 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-9-21
#     -> parsed rows: 935354 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-9-22
#     -> parsed rows: 935398 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-9-23
#     -> parsed rows: 177353 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-9-3
#     -> parsed rows: 935339 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-9-4
#     -> parsed rows: 935395 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-9-5
#     -> parsed rows: 935363 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-9-6
#     -> parsed rows: 935426 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-9-7
#     -> parsed rows: 295819 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-9-9
#     -> parsed rows: 935439 | bad rows: 0
# [MERGE] Concatenating 149 dataframes...
# [INFO] Total rows: 127235800
# [CLEAN] Converting timestamps...
# [CLEAN] Dropping bad rows: 251338
# [CALC] Computing latency...
# [SORT] Sorting by processed_time...
# [DONE] Node n1 ready
#
# ================ LATENCY SUMMARY ================
#
# [n1]
#   Avg latency : 137011.55 ms
#   P50 latency : 150861.00 ms
#   P95 latency : 256370.00 ms
#   P99 latency : 266356.00 ms
#
#
# ========================================
# [TAR] Processing: nexmark_fails_10p_q1_n0
# [NODE] Detected node: n0
# [CLEAN] Removing old extracted folder
# [EXTRACT] Extracting fails_flink/nexmark_fails_10p_q1_n0.tar
# [MOVE] Moving to fails_flink/extracted_nexmark_fails_10p_q1_n0
# [DATA] Looking in: fails_flink/extracted_nexmark_fails_10p_q1_n0/mnt/nfs/flink/nexmark/q1
# [INFO] Found 84 part files
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-2-0
#     -> parsed rows: 935425 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-2-1
#     -> parsed rows: 935341 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-2-10
#     -> parsed rows: 935361 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-2-11
#     -> parsed rows: 406681 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-2-12
#     -> parsed rows: 935312 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-2-13
#     -> parsed rows: 935397 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-2-14
#     -> parsed rows: 935335 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-2-15
#     -> parsed rows: 935391 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-2-16
#     -> parsed rows: 935348 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-2-17
#     -> parsed rows: 935437 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-2-18
#     -> parsed rows: 935453 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-2-19
#     -> parsed rows: 935396 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-2-2
#     -> parsed rows: 935334 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-2-20
#     -> parsed rows: 935402 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-2-21
#     -> parsed rows: 935344 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-2-22
#     -> parsed rows: 935454 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-2-23
#     -> parsed rows: 778040 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-2-3
#     -> parsed rows: 935459 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-2-4
#     -> parsed rows: 935467 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-2-5
#     -> parsed rows: 935445 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-2-6
#     -> parsed rows: 935415 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-2-7
#     -> parsed rows: 935410 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-2-8
#     -> parsed rows: 120228 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-2-9
#     -> parsed rows: 935355 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-4-10
#     -> parsed rows: 928939 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-4-11
#     -> parsed rows: 392319 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-4-12
#     -> parsed rows: 928917 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-4-13
#     -> parsed rows: 929003 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-4-14
#     -> parsed rows: 928877 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-4-15
#     -> parsed rows: 928927 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-4-16
#     -> parsed rows: 928876 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-4-17
#     -> parsed rows: 928837 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-4-18
#     -> parsed rows: 928970 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-4-19
#     -> parsed rows: 928926 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-4-20
#     -> parsed rows: 928972 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-4-21
#     -> parsed rows: 928977 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-4-22
#     -> parsed rows: 928997 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-4-23
#     -> parsed rows: 554988 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-4-9
#     -> parsed rows: 928968 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-5-0
#     -> parsed rows: 928966 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-5-1
#     -> parsed rows: 928957 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-5-10
#     -> parsed rows: 928971 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-5-11
#     -> parsed rows: 488756 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-5-12
#     -> parsed rows: 928992 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-5-13
#     -> parsed rows: 928785 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-5-14
#     -> parsed rows: 928887 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-5-15
#     -> parsed rows: 928809 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-5-16
#     -> parsed rows: 928849 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-5-17
#     -> parsed rows: 928904 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-5-18
#     -> parsed rows: 929039 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-5-19
#     -> parsed rows: 928930 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-5-2
#     -> parsed rows: 928998 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-5-20
#     -> parsed rows: 928989 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-5-21
#     -> parsed rows: 928931 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-5-22
#     -> parsed rows: 928967 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-5-23
#     -> parsed rows: 729554 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-5-3
#     -> parsed rows: 928976 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-5-4
#     -> parsed rows: 928874 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-5-5
#     -> parsed rows: 928907 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-5-6
#     -> parsed rows: 929054 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-5-7
#     -> parsed rows: 605017 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-5-9
#     -> parsed rows: 928943 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-7-0
#     -> parsed rows: 972877 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-7-1
#     -> parsed rows: 966187 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-7-10
#     -> parsed rows: 955396 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-7-11
#     -> parsed rows: 408166 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-7-12
#     -> parsed rows: 955406 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-7-13
#     -> parsed rows: 955324 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-7-14
#     -> parsed rows: 955410 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-7-15
#     -> parsed rows: 955402 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-7-16
#     -> parsed rows: 955337 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-7-17
#     -> parsed rows: 955354 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-7-18
#     -> parsed rows: 954596 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-7-19
#     -> parsed rows: 948696 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-7-2
#     -> parsed rows: 962258 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-7-20
#     -> parsed rows: 948528 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-7-21
#     -> parsed rows: 948560 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-7-22
#     -> parsed rows: 948518 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-7-23
#     -> parsed rows: 642384 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-7-3
#     -> parsed rows: 962223 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-7-4
#     -> parsed rows: 960033 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-7-5
#     -> parsed rows: 955290 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-7-6
#     -> parsed rows: 649494 | bad rows: 0
# [FILE] Processing: part-52c2ab0e-9589-4800-a387-44566da0b31e-7-9
#     -> parsed rows: 955409 | bad rows: 0
# [MERGE] Concatenating 84 dataframes...
# [INFO] Total rows: 74244626
# [CLEAN] Converting timestamps...
# [CLEAN] Dropping bad rows: 146206
# [CALC] Computing latency...
# [SORT] Sorting by processed_time...
# [DONE] Node n0 ready
#
# ================ LATENCY SUMMARY ================
#
# [n1]
#   Avg latency : 137011.55 ms
#   P50 latency : 150861.00 ms
#   P95 latency : 256370.00 ms
#   P99 latency : 266356.00 ms
#
# [n0]
#   Avg latency : 152051.15 ms
#   P50 latency : 166691.00 ms
#   P95 latency : 257224.00 ms
#   P99 latency : 264945.00 ms

# %%
# ===================== ANALYSIS =====================
def smooth(series, w=5):
    return series.rolling(w, min_periods=1).mean()

def compute_latency(df):
    r = df["latency_ms"].resample(f"{window_seconds}s")
    return pd.DataFrame({
        "p50": r.quantile(0.5),
        "p95": r.quantile(0.95),
        "p99": r.quantile(0.99),
    })

def compute_throughput(df):
    return df["auction"].resample(f"{window_seconds}s").size()

def detect_failures(tp):
    gaps = []
    start = None

    for ts, v in tp.items():
        if v == 0 and start is None:
            start = ts
        elif v > 0 and start is not None:
            gaps.append((start, ts))
            start = None

    return gaps

# %%
# ===================== PLOTTING =====================
print("[PLOT] Latency plot...")
plt.figure()

node_colors = {"n0": "blue", "n1": "orange"}
all_failures = []
# Out:
# [PLOT] Latency plot...

# %%
for node, df in node_data.items():
    lat = compute_latency(df)

    plt.plot(smooth(lat["p50"]), label=f"{node} p50", color=node_colors.get(node))
    plt.plot(smooth(lat["p95"]), linestyle="--", label=f"{node} p95", color=node_colors.get(node))
    plt.plot(smooth(lat["p99"]), linestyle=":", label=f"{node} p99", color=node_colors.get(node))

plt.title(f"Latency ({query})")
plt.xlabel("Time")
plt.ylabel("ms")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig(output_dir / f"latency_{query}.png")
plt.close()

print("[PLOT] Throughput plot...")
plt.figure()
# Out:
# [PLOT] Throughput plot...

# %%
for node, df in node_data.items():
    tp = compute_throughput(df)
    tp_s = smooth(tp)

    plt.plot(tp_s, label=node, color=node_colors.get(node))

    gaps = detect_failures(tp)
    for start, end in gaps:
        all_failures.append((start, end, node))

for start, end, node in all_failures:
    plt.axvspan(start, end, alpha=0.15, color=node_colors.get(node))
    mid = start + (end - start) / 2
    plt.text(mid, plt.ylim()[1] * 0.8, f"{node}", rotation=90, ha="center")

# %%
plt.title(f"Throughput ({query})")
plt.xlabel("Time")
plt.ylabel("events/sec")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig(output_dir / f"throughput_{query}.png")
plt.close()

print("[COMPLETE] Done. Outputs in:", output_dir)
# Out:
# [COMPLETE] Done. Outputs in: analysis_output/fails/q1
# /var/folders/q5/_vyqqcz16vg3sg5pn1mmprcw0000gn/T/ipykernel_13990/3772911770.py:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
df.head(2)
# Out:
#                          auction  bidder        price              event_time  \
# processed_time
# 2026-04-12 01:49:33.681     1002    1002    14307.356 2026-04-12 01:49:29.767
# 2026-04-12 01:49:33.682     1004    1004  6283083.060 2026-04-12 01:49:29.767
#
#                                                                      extra  \
# processed_time
# 2026-04-12 01:49:33.681  scyeznjaqe\UMQR`JVSY`JZ[HXaIbgecwcN[MH\R_SWHX[...
# 2026-04-12 01:49:33.682  cdjnkiwblflduauagfqzamlvsvdkedZa^VTHagoizf`IRK...
#
#                          latency_ms
# processed_time
# 2026-04-12 01:49:33.681      3914.0
# 2026-04-12 01:49:33.682      3915.0
