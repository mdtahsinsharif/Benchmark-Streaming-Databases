# %%
import sys
print(sys.executable)
# Out:
# /Users/mdtahsinsharif/anaconda3/envs/stream-metrics/bin/python

# %%
import os
import tarfile
import shutil
import glob
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# %%
# ===================== CONFIG =====================
query = "q10"
failure = "fails"
base_dir = Path("fails_flink")
output_dir = Path("analysis_output") / failure / query
window_seconds = 5
# ==================================================

# %%
output_dir.mkdir(exist_ok=True)

print("[START] Analysis pipeline starting...")
print(f"Query: {query}")
print(f"Base dir: {base_dir}")
print(f"Output dir: {output_dir}")

pattern = f"nexmark_{failure}_10p_{query}_*.tar"
tar_files = list(base_dir.glob(pattern))

print(f"[INFO] Found {len(tar_files)} tar files")

if not tar_files:
    print(f"No tar files found for {query}")
    exit(1)

node_data = {}
# Out:
# [START] Analysis pipeline starting...
# Query: q10
# Base dir: fails_flink
# Output dir: analysis_output/fails/q10
# [INFO] Found 2 tar files

# %%
def compute_latency_summary(df):
    return {
        "avg": df["latency_ms"].mean(),
        "p50": df["latency_ms"].quantile(0.50),
        "p95": df["latency_ms"].quantile(0.95),
        "p99": df["latency_ms"].quantile(0.99),
    }

# %%
def parse_part_file(pf):
    rows = []
    bad = 0

    print(f"[FILE] Processing: {os.path.basename(pf)}")

    max_errors_to_show = 5
    error_count = 0

    with open(pf, "r", errors="ignore") as f:
        for line_num, line in enumerate(f, 1):

            parts = line.rstrip("\n").split(",", 7)

            # Q10 expects at least 8 fields
            if len(parts) < 6:
                bad += 1
                if error_count < max_errors_to_show:
                    print(f"[WARN] Line {line_num}: insufficient columns -> {line.strip()}")
                    error_count += 1
                continue

            try:
                auction = parts[0]
                bidder = parts[1]
                price = parts[2]
                event_time = parts[3].strip('"')
                extra = parts[4]
                processed_time = parts[5].strip('"')

                rows.append({
                    "auction": int(auction),
                    "bidder": int(bidder),
                    "price": float(price),
                    "event_time": event_time,
                    "extra": extra,
                    "processed_time": processed_time
                })

            except Exception as e:
                bad += 1
                if error_count < max_errors_to_show:
                    print(f"[ERROR] Line {line_num}: {e}")
                    print(f"        data: {line.strip()}")
                    error_count += 1

    print(f"    -> parsed rows: {len(rows)} | bad rows: {bad}")
    return pd.DataFrame(rows)

# %%
# ===================== MAIN LOOP =====================
for tar_path in tar_files:
    tar_name = tar_path.stem
    node = tar_name.split("_")[-1]

    print("\n========================================")
    print(f"[TAR] Processing: {tar_name}")
    print(f"[NODE] Detected node: {node}")

    extract_root = base_dir / f"extracted_{tar_name}"
    temp_extract = base_dir / "_tmp_extract"

    flink_path = extract_root / "flink" / "nexmark" / query

    # -------- Extraction --------
    if extract_root.exists() and flink_path.exists():
        print(f"[SKIP] Already extracted: {extract_root}")
    else:
        if extract_root.exists():
            print("[CLEAN] Removing old extracted folder")
            shutil.rmtree(extract_root)

        if temp_extract.exists():
            shutil.rmtree(temp_extract)

        temp_extract.mkdir(parents=True, exist_ok=True)

        print(f"[EXTRACT] Extracting {tar_path}")
        #with tarfile.open(tar_path) as tar:
        #    tar.extractall(path=temp_extract)
        
        with tarfile.open(tar_path, mode="r:*") as tar:
            tar.extractall(path=temp_extract)

        print(f"[MOVE] Moving to {extract_root}")
        extract_root.mkdir(parents=True, exist_ok=True)

        extracted_items = list(temp_extract.iterdir())

        if len(extracted_items) == 1 and extracted_items[0].is_dir():
            shutil.move(str(extracted_items[0]), str(extract_root))
        else:
            for item in extracted_items:
                shutil.move(str(item), str(extract_root))

        shutil.rmtree(temp_extract)

    # -------- Data path --------
    data_path = extract_root / "mnt" / "nfs" / "flink" / "nexmark" / query
    print(f"[DATA] Looking in: {data_path}")

    #part_files = sorted(glob.glob(str(data_path / "part-*")))
    part_files = sorted(
        glob.glob(str(data_path / "**" / "part-*"), recursive=True)
    )
    print(f"[INFO] Found {len(part_files)} part files")

    if not part_files:
        print(f"[WARN] No part files for {node}")
        continue

    # -------- Load files --------
    dfs = []

    for pf in part_files:
        df_part = parse_part_file(pf)
        if not df_part.empty:
            dfs.append(df_part)

    if not dfs:
        print(f"[ERROR] No usable data for {node}")
        continue

    print(f"[MERGE] Concatenating {len(dfs)} dataframes...")
    df = pd.concat(dfs, ignore_index=True)
    print(f"[INFO] Total rows: {len(df)}")

    # -------- Clean timestamps --------
    print("[CLEAN] Converting timestamps...")
    df["event_time"] = pd.to_datetime(df["event_time"], errors="coerce")
    df["processed_time"] = pd.to_datetime(df["processed_time"], errors="coerce")

    bad_rows = df["event_time"].isna() | df["processed_time"].isna()
    print(f"[CLEAN] Dropping bad rows: {bad_rows.sum()}")

    df = df[~bad_rows]

    # -------- Latency --------
    print("[CALC] Computing latency...")
    df["processed_time"] = df["processed_time"] + pd.Timedelta(hours=4)
    
    df["latency_ms"] = (
        (df["processed_time"] - df["event_time"])
        .dt.total_seconds() * 1000
    )

    print("[SORT] Sorting by processed_time...")
    df = df.sort_values("processed_time").set_index("processed_time")

    node_data[node] = df
    print(f"[DONE] Node {node} ready")
    
    print("\n================ LATENCY SUMMARY ================\n")

    global_df = []

    for node, df in node_data.items():
        stats = compute_latency_summary(df)

        print(f"[{node}]")
        print(f"  Avg latency : {stats['avg']:.2f} ms")
        print(f"  P50 latency : {stats['p50']:.2f} ms")
        print(f"  P95 latency : {stats['p95']:.2f} ms")
        print(f"  P99 latency : {stats['p99']:.2f} ms")
        print()
# Out:
# ========================================
# [TAR] Processing: nexmark_fails_10p_q10_n0
# [NODE] Detected node: n0
# [CLEAN] Removing old extracted folder
# [EXTRACT] Extracting fails_flink/nexmark_fails_10p_q10_n0.tar
# [MOVE] Moving to fails_flink/extracted_nexmark_fails_10p_q10_n0
# [DATA] Looking in: fails_flink/extracted_nexmark_fails_10p_q10_n0/mnt/nfs/flink/nexmark/q10
# [INFO] Found 94 part files
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-1-0
#     -> parsed rows: 957006 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-1-1
#     -> parsed rows: 950643 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-1-2
#     -> parsed rows: 946744 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-1-3
#     -> parsed rows: 946692 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-1-4
#     -> parsed rows: 504006 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-1-6
#     -> parsed rows: 941598 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-1-7
#     -> parsed rows: 940001 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-1-8
#     -> parsed rows: 492326 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-3-0
#     -> parsed rows: 914447 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-3-1
#     -> parsed rows: 914424 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-3-2
#     -> parsed rows: 914363 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-3-3
#     -> parsed rows: 914402 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-3-4
#     -> parsed rows: 914410 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-3-5
#     -> parsed rows: 23558 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-3-6
#     -> parsed rows: 914477 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-3-7
#     -> parsed rows: 914488 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-3-8
#     -> parsed rows: 254447 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-4-0
#     -> parsed rows: 920722 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-4-1
#     -> parsed rows: 920666 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-4-2
#     -> parsed rows: 920647 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-4-3
#     -> parsed rows: 920681 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-4-4
#     -> parsed rows: 623719 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-4-6
#     -> parsed rows: 920713 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-4-7
#     -> parsed rows: 920734 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-4-8
#     -> parsed rows: 531134 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-8-6
#     -> parsed rows: 914522 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-8-7
#     -> parsed rows: 914517 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-8-8
#     -> parsed rows: 687664 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-1-10
#     -> parsed rows: 940139 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-1-11
#     -> parsed rows: 940057 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-1-12
#     -> parsed rows: 940084 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-1-13
#     -> parsed rows: 739412 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-1-14
#     -> parsed rows: 940105 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-1-15
#     -> parsed rows: 940162 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-1-16
#     -> parsed rows: 940084 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-1-17
#     -> parsed rows: 940007 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-1-18
#     -> parsed rows: 936061 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-1-19
#     -> parsed rows: 933438 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-1-20
#     -> parsed rows: 910324 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-1-9
#     -> parsed rows: 940127 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-3-10
#     -> parsed rows: 914328 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-3-11
#     -> parsed rows: 914494 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-3-12
#     -> parsed rows: 914418 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-3-13
#     -> parsed rows: 914467 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-3-14
#     -> parsed rows: 373313 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-3-15
#     -> parsed rows: 914358 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-3-16
#     -> parsed rows: 914369 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-3-17
#     -> parsed rows: 914421 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-3-18
#     -> parsed rows: 914488 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-3-19
#     -> parsed rows: 914519 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-3-20
#     -> parsed rows: 914379 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-3-21
#     -> parsed rows: 607888 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-3-9
#     -> parsed rows: 914558 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-4-10
#     -> parsed rows: 920605 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-4-11
#     -> parsed rows: 920688 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-4-12
#     -> parsed rows: 920711 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-4-13
#     -> parsed rows: 556550 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-4-14
#     -> parsed rows: 920741 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-4-15
#     -> parsed rows: 920797 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-4-16
#     -> parsed rows: 920672 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-4-17
#     -> parsed rows: 920658 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-4-18
#     -> parsed rows: 920761 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-4-19
#     -> parsed rows: 920729 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-4-20
#     -> parsed rows: 920607 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-4-21
#     -> parsed rows: 355791 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-4-9
#     -> parsed rows: 920690 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-8-10
#     -> parsed rows: 914365 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-8-11
#     -> parsed rows: 914323 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-8-12
#     -> parsed rows: 914389 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-8-13
#     -> parsed rows: 516654 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-8-14
#     -> parsed rows: 914402 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-8-15
#     -> parsed rows: 914405 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-8-16
#     -> parsed rows: 914421 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-8-17
#     -> parsed rows: 914439 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-8-18
#     -> parsed rows: 914472 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-8-19
#     -> parsed rows: 914373 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-8-20
#     -> parsed rows: 914420 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-8-21
#     -> parsed rows: 464890 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-8-9
#     -> parsed rows: 914447 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-1-21
#     -> parsed rows: 933686 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-1-22
#     -> parsed rows: 933544 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-1-23
#     -> parsed rows: 933488 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-1-24
#     -> parsed rows: 354883 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-3-22
#     -> parsed rows: 914416 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-3-23
#     -> parsed rows: 914427 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-3-24
#     -> parsed rows: 914402 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-3-25
#     -> parsed rows: 914419 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-3-26
#     -> parsed rows: 121007 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-4-22
#     -> parsed rows: 920779 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-4-23
#     -> parsed rows: 920745 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-4-24
#     -> parsed rows: 520643 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-8-22
#     -> parsed rows: 914452 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-8-23
#     -> parsed rows: 914400 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-8-24
#     -> parsed rows: 341460 | bad rows: 0
# [MERGE] Concatenating 94 dataframes...
# [INFO] Total rows: 78180502
# [CLEAN] Converting timestamps...
# [CLEAN] Dropping bad rows: 153640
# [CALC] Computing latency...
# [SORT] Sorting by processed_time...
# [DONE] Node n0 ready
#
# ================ LATENCY SUMMARY ================
#
# [n0]
#   Avg latency : 212294.82 ms
#   P50 latency : 224643.00 ms
#   P95 latency : 344425.00 ms
#   P99 latency : 355394.00 ms
#
#
# ========================================
# [TAR] Processing: nexmark_fails_10p_q10_n1
# [NODE] Detected node: n1
# [EXTRACT] Extracting fails_flink/nexmark_fails_10p_q10_n1.tar
# [MOVE] Moving to fails_flink/extracted_nexmark_fails_10p_q10_n1
# [DATA] Looking in: fails_flink/extracted_nexmark_fails_10p_q10_n1/mnt/nfs/flink/nexmark/q10
# [INFO] Found 153 part files
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-0-0
#     -> parsed rows: 908301 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-0-1
#     -> parsed rows: 908236 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-0-2
#     -> parsed rows: 908234 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-0-3
#     -> parsed rows: 908276 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-0-4
#     -> parsed rows: 814075 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-0-6
#     -> parsed rows: 908180 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-0-7
#     -> parsed rows: 908276 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-0-8
#     -> parsed rows: 415438 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-2-0
#     -> parsed rows: 914362 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-2-1
#     -> parsed rows: 914493 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-2-2
#     -> parsed rows: 914498 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-2-3
#     -> parsed rows: 914363 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-2-4
#     -> parsed rows: 852704 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-2-6
#     -> parsed rows: 914400 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-2-7
#     -> parsed rows: 914378 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-2-8
#     -> parsed rows: 339818 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-5-0
#     -> parsed rows: 914481 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-5-1
#     -> parsed rows: 914455 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-5-2
#     -> parsed rows: 914420 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-5-3
#     -> parsed rows: 914484 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-5-4
#     -> parsed rows: 835283 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-5-6
#     -> parsed rows: 914508 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-5-7
#     -> parsed rows: 914472 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-5-8
#     -> parsed rows: 356913 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-6-0
#     -> parsed rows: 914372 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-6-1
#     -> parsed rows: 914480 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-6-2
#     -> parsed rows: 914401 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-6-3
#     -> parsed rows: 914521 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-6-4
#     -> parsed rows: 576869 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-6-6
#     -> parsed rows: 914388 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-6-7
#     -> parsed rows: 914483 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-6-8
#     -> parsed rows: 615502 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-7-0
#     -> parsed rows: 920714 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-7-1
#     -> parsed rows: 920800 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-7-2
#     -> parsed rows: 920696 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-7-3
#     -> parsed rows: 920692 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-7-4
#     -> parsed rows: 816223 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-7-6
#     -> parsed rows: 920635 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-7-7
#     -> parsed rows: 920780 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-7-8
#     -> parsed rows: 338476 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-8-0
#     -> parsed rows: 914359 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-8-1
#     -> parsed rows: 914487 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-8-2
#     -> parsed rows: 914441 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-8-3
#     -> parsed rows: 914355 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-8-4
#     -> parsed rows: 504671 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-9-0
#     -> parsed rows: 914494 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-9-1
#     -> parsed rows: 914521 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-9-2
#     -> parsed rows: 914363 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-9-3
#     -> parsed rows: 914518 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-9-4
#     -> parsed rows: 608181 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-9-6
#     -> parsed rows: 914538 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-9-7
#     -> parsed rows: 914417 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-9-8
#     -> parsed rows: 583984 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-0-10
#     -> parsed rows: 908220 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-0-11
#     -> parsed rows: 908232 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-0-12
#     -> parsed rows: 908175 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-0-13
#     -> parsed rows: 908239 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-0-14
#     -> parsed rows: 39051 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-0-15
#     -> parsed rows: 908199 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-0-16
#     -> parsed rows: 908312 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-0-17
#     -> parsed rows: 908269 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-0-18
#     -> parsed rows: 908336 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-0-19
#     -> parsed rows: 908297 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-0-20
#     -> parsed rows: 908266 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-0-21
#     -> parsed rows: 908262 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-0-22
#     -> parsed rows: 101907 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-0-9
#     -> parsed rows: 908235 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-2-10
#     -> parsed rows: 914401 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-2-11
#     -> parsed rows: 914515 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-2-12
#     -> parsed rows: 914456 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-2-13
#     -> parsed rows: 914493 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-2-14
#     -> parsed rows: 161086 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-2-15
#     -> parsed rows: 914427 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-2-16
#     -> parsed rows: 914345 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-2-17
#     -> parsed rows: 914409 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-2-18
#     -> parsed rows: 914423 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-2-19
#     -> parsed rows: 914427 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-2-20
#     -> parsed rows: 914428 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-2-21
#     -> parsed rows: 820124 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-2-9
#     -> parsed rows: 914466 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-5-10
#     -> parsed rows: 914529 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-5-11
#     -> parsed rows: 914450 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-5-12
#     -> parsed rows: 914425 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-5-13
#     -> parsed rows: 914478 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-5-14
#     -> parsed rows: 1 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-5-15
#     -> parsed rows: 914502 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-5-16
#     -> parsed rows: 914500 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-5-17
#     -> parsed rows: 914543 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-5-18
#     -> parsed rows: 914315 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-5-19
#     -> parsed rows: 914435 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-5-20
#     -> parsed rows: 914412 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-5-21
#     -> parsed rows: 914366 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-5-22
#     -> parsed rows: 66564 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-5-9
#     -> parsed rows: 914480 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-6-10
#     -> parsed rows: 914416 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-6-11
#     -> parsed rows: 914487 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-6-12
#     -> parsed rows: 744157 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-6-13
#     -> parsed rows: 914497 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-6-14
#     -> parsed rows: 914470 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-6-15
#     -> parsed rows: 914442 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-6-16
#     -> parsed rows: 914383 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-6-17
#     -> parsed rows: 914404 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-6-18
#     -> parsed rows: 914491 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-6-19
#     -> parsed rows: 914429 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-6-20
#     -> parsed rows: 914402 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-6-21
#     -> parsed rows: 237012 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-6-9
#     -> parsed rows: 914410 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-7-10
#     -> parsed rows: 920651 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-7-11
#     -> parsed rows: 920748 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-7-12
#     -> parsed rows: 920761 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-7-13
#     -> parsed rows: 691292 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-7-14
#     -> parsed rows: 920727 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-7-15
#     -> parsed rows: 920670 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-7-16
#     -> parsed rows: 920651 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-7-17
#     -> parsed rows: 920728 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-7-18
#     -> parsed rows: 920650 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-7-19
#     -> parsed rows: 920721 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-7-20
#     -> parsed rows: 920794 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-7-21
#     -> parsed rows: 220922 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-7-9
#     -> parsed rows: 920685 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-9-10
#     -> parsed rows: 914559 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-9-11
#     -> parsed rows: 914509 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-9-12
#     -> parsed rows: 914445 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-9-13
#     -> parsed rows: 532889 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-9-14
#     -> parsed rows: 914401 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-9-15
#     -> parsed rows: 914422 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-9-16
#     -> parsed rows: 914440 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-9-17
#     -> parsed rows: 914526 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-9-18
#     -> parsed rows: 914328 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-9-19
#     -> parsed rows: 914510 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-9-20
#     -> parsed rows: 914449 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-9-21
#     -> parsed rows: 447956 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-9-9
#     -> parsed rows: 914566 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-0-23
#     -> parsed rows: 908189 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-0-24
#     -> parsed rows: 908351 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-0-25
#     -> parsed rows: 908279 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-0-26
#     -> parsed rows: 908262 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-0-27
#     -> parsed rows: 37427 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-2-22
#     -> parsed rows: 914435 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-2-23
#     -> parsed rows: 914487 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-2-24
#     -> parsed rows: 914508 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-2-25
#     -> parsed rows: 874865 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-5-23
#     -> parsed rows: 914543 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-5-24
#     -> parsed rows: 914427 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-5-25
#     -> parsed rows: 914495 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-5-26
#     -> parsed rows: 601903 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-6-22
#     -> parsed rows: 898347 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-7-22
#     -> parsed rows: 920738 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-7-23
#     -> parsed rows: 920643 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-7-24
#     -> parsed rows: 837473 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-9-22
#     -> parsed rows: 914444 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-9-23
#     -> parsed rows: 914400 | bad rows: 0
# [FILE] Processing: part-6f4011dc-42d0-4630-a987-197c76e99b96-9-24
#     -> parsed rows: 764830 | bad rows: 0
# [MERGE] Concatenating 153 dataframes...
# [INFO] Total rows: 127281455
# [CLEAN] Converting timestamps...
# [CLEAN] Dropping bad rows: 250754
# [CALC] Computing latency...
# [SORT] Sorting by processed_time...
# [DONE] Node n1 ready
#
# ================ LATENCY SUMMARY ================
#
# [n0]
#   Avg latency : 212294.82 ms
#   P50 latency : 224643.00 ms
#   P95 latency : 344425.00 ms
#   P99 latency : 355394.00 ms
#
# [n1]
#   Avg latency : 198685.11 ms
#   P50 latency : 215302.00 ms
#   P95 latency : 343835.00 ms
#   P99 latency : 355950.00 ms

# %%
# ===================== ANALYSIS =====================
def smooth(series, w=5):
    return series.rolling(w, min_periods=1).mean()

def compute_latency(df):
    r = df["latency_ms"].resample(f"{window_seconds}s")
    return pd.DataFrame({
        "p50": r.quantile(0.5),
        "p95": r.quantile(0.95),
        "p99": r.quantile(0.99),
    })

def compute_throughput(df):
    return df["auction"].resample(f"{window_seconds}s").size()

def detect_failures(tp):
    gaps = []
    start = None

    for ts, v in tp.items():
        if v == 0 and start is None:
            start = ts
        elif v > 0 and start is not None:
            gaps.append((start, ts))
            start = None

    return gaps

# %%
# ===================== PLOTTING =====================
print("[PLOT] Latency plot...")
plt.figure()

node_colors = {"n0": "blue", "n1": "orange"}
all_failures = []
# Out:
# [PLOT] Latency plot...

# %%
for node, df in node_data.items():
    lat = compute_latency(df)

    plt.plot(smooth(lat["p50"]), label=f"{node} p50", color=node_colors.get(node))
    plt.plot(smooth(lat["p95"]), linestyle="--", label=f"{node} p95", color=node_colors.get(node))
    plt.plot(smooth(lat["p99"]), linestyle=":", label=f"{node} p99", color=node_colors.get(node))

plt.title(f"Latency ({query})")
plt.xlabel("Time")
plt.ylabel("ms")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig(output_dir / f"latency_{query}.png")
plt.close()

print("[PLOT] Throughput plot...")
plt.figure()
# Out:
# [PLOT] Throughput plot...

# %%
for node, df in node_data.items():
    tp = compute_throughput(df)
    tp_s = smooth(tp)

    plt.plot(tp_s, label=node, color=node_colors.get(node))

    gaps = detect_failures(tp)
    for start, end in gaps:
        all_failures.append((start, end, node))

for start, end, node in all_failures:
    plt.axvspan(start, end, alpha=0.15, color=node_colors.get(node))
    mid = start + (end - start) / 2
    plt.text(mid, plt.ylim()[1] * 0.8, f"{node}", rotation=90, ha="center")

# %%
plt.title(f"Throughput ({query})")
plt.xlabel("Time")
plt.ylabel("events/sec")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig(output_dir / f"throughput_{query}.png")
plt.close()

print("[COMPLETE] Done. Outputs in:", output_dir)
# Out:
# [COMPLETE] Done. Outputs in: analysis_output/fails/q10
# /var/folders/q5/_vyqqcz16vg3sg5pn1mmprcw0000gn/T/ipykernel_13989/3772911770.py:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
df.head(2)
# Out:
#                           auction    bidder    price              event_time  \
# processed_time
# 2026-04-12 04:15:27.448  12000972   4002001    305.0 2026-04-12 04:15:23.701
# 2026-04-12 04:15:27.510  36000970  12002001  33545.0 2026-04-12 04:15:23.701
#
#                                                                      extra  \
# processed_time
# 2026-04-12 04:15:27.448  "whndmwmlxgbLH]OZV]_aKa[URZLRJYOHQ_[UKTIK\tvpa...
# 2026-04-12 04:15:27.510  "ofzgz`VUZOWM]^KPS^PQPUVwtankitzjzsqKW[^OLcbzc...
#
#                          latency_ms
# processed_time
# 2026-04-12 04:15:27.448      3747.0
# 2026-04-12 04:15:27.510      3809.0
