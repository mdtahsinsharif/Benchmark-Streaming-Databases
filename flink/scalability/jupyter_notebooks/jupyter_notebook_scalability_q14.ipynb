# %%
import sys
print(sys.executable)
# Out:
# /Users/mdtahsinsharif/anaconda3/envs/stream-metrics/bin/python

# %%
import os
import tarfile
import shutil
import glob
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# %%
# ===================== CONFIG =====================
query = "q14"
failure = "scalability"
cores_list = ["p1", "p4", "p10", "p20", "p30"]
#base_dir = Path(failure + "_flink")
base_dir = Path.cwd()
output_dir = Path("analysis_output") / failure / query
window_seconds = 5
# ==================================================

# %%
output_dir.mkdir(parents=True, exist_ok=True)

print("[START] Analysis pipeline starting...")
print(f"Query: {query}")
print(f"Base dir: {base_dir}")
print(f"Output dir: {output_dir}")

pattern = f"nexmark_{failure}_10p_{query}_*"
run_dirs = sorted([p for p in base_dir.glob(pattern) if p.is_dir()])

print(f"[INFO] Found {len(run_dirs)} run directories")

if not run_dirs:
    print(f"No runs found for {query}")
    exit(1)

node_data = {}
throughput_summary = {}  # {node: {cores: throughput}}
cluster_throughput = {}
# Out:
# [START] Analysis pipeline starting...
# Query: q14
# Base dir: /Users/mdtahsinsharif/Desktop/Tahsin/Tahsin/tahsinTransferred/tahsinNewLaptop/studies/ece1724/project/metrics/scalability_flink
# Output dir: analysis_output/scalability/q14
# [INFO] Found 2 run directories

# %%
# ===================== HELPERS =====================
def compute_latency_summary(df):
    return {
        "avg": df["latency_ms"].mean(),
        "p50": df["latency_ms"].quantile(0.50),
        "p95": df["latency_ms"].quantile(0.95),
        "p99": df["latency_ms"].quantile(0.99),
    }

def compute_latency(df):
    r = df["latency_ms"].resample(f"{window_seconds}s")
    return pd.DataFrame({
        "p50": r.quantile(0.5),
        "p95": r.quantile(0.95),
        "p99": r.quantile(0.99),
    })

def compute_throughput(df):
    return df["auction"].resample(f"{window_seconds}s").size()

def smooth(series, w=5):
    return series.rolling(w, min_periods=1).mean()

def detect_failures(tp):
    gaps = []
    start = None

    for ts, v in tp.items():
        if v == 0 and start is None:
            start = ts
        elif v > 0 and start is not None:
            gaps.append((start, ts))
            start = None

    return gaps

# %%
def parse_part_file(pf):
    rows = []
    bad = 0

    print(f"[FILE] Processing: {os.path.basename(pf)}")

    with open(pf, "r", errors="ignore") as f:
        for line_num, line in enumerate(f, 1):
            parts = line.rstrip("\n").split(",")

            if len(parts) < 8:
                bad += 1
                continue

            #auction, price, event_time, processed_time = parts

            try:
                auction = parts[0]
                bidder = parts[1]
                bidder2 = parts[2]
                timeofday = parts[3]
                event_time = parts[4].strip('"')
                processed_time = parts[5].strip('"')
                extra = parts[6]
                booleannumber = parts[7]

                rows.append({
                    "auction": int(auction),
                    "bidder": int(bidder),
                    "bidder2": float(bidder2),
                    "timeofday": str(timeofday),
                    "event_time": event_time,
                    "processed_time": processed_time,
                    "extra": extra,
                    "booleannumber": int(booleannumber)
                })
            except:
                bad += 1

    print(f"    -> parsed rows: {len(rows)} | bad rows: {bad}")
    return pd.DataFrame(rows)

# %%
# ===================== MAIN LOOP =====================
for run_dir in run_dirs:
    tar_name = run_dir.name
    node = tar_name.split("_")[-1]

    print("\n========================================")
    print(f"[RUN] {tar_name}")
    print(f"[NODE] {node}")

    for cores in cores_list:
        data_path = run_dir / "nfs" / "flink" / "nexmark" / failure / query / cores

        print(f"[DATA] {cores} → {data_path}")

        if not data_path.exists():
            print(f"[WARN] Missing path")
            continue

        part_files = sorted(
            glob.glob(str(data_path / "**" / "part-*"), recursive=True)
        )

        if not part_files:
            print(f"[WARN] No part files")
            continue

        dfs = []
        for pf in part_files:
            df_part = parse_part_file(pf)
            if not df_part.empty:
                dfs.append(df_part)

        if not dfs:
            continue

        df = pd.concat(dfs, ignore_index=True)

        # ---- timestamps ----
        df["event_time"] = pd.to_datetime(df["event_time"], errors="coerce")
        df["processed_time"] = pd.to_datetime(df["processed_time"], errors="coerce")

        df = df.dropna(subset=["event_time", "processed_time"])

        df["processed_time"] += pd.Timedelta(hours=4)

        # ---- latency ----
        df["latency_ms"] = (
            (df["processed_time"] - df["event_time"])
            .dt.total_seconds() * 1000
        )

        df = df.sort_values("processed_time").set_index("processed_time")

        # store only one core (for time-series plots)
        if cores == "p10":
            node_data[node] = df

        # ---- throughput summary ----
        tp = compute_throughput(df)

        # steady-state avg (ignore first 20%)
        tp_ss = tp[int(len(tp)*0.2):]
        avg_tp = tp_ss.mean() if not tp_ss.empty else tp.mean()

        throughput_summary.setdefault(node, {})[cores] = avg_tp

        print(f"[TP] {node} {cores}: {avg_tp:.2f}")

# ===================== LATENCY SUMMARY =====================
print("\n================ LATENCY SUMMARY ================\n")

for node, df in node_data.items():
    stats = compute_latency_summary(df)

    print(f"[{node}]")
    print(f"  Avg latency : {stats['avg']:.2f} ms")
    print(f"  P50 latency : {stats['p50']:.2f} ms")
    print(f"  P95 latency : {stats['p95']:.2f} ms")
    print(f"  P99 latency : {stats['p99']:.2f} ms")
    print()
# Out:
# ========================================
# [RUN] nexmark_scalability_10p_q14_n0
# [NODE] n0
# [DATA] p1 → /Users/mdtahsinsharif/Desktop/Tahsin/Tahsin/tahsinTransferred/tahsinNewLaptop/studies/ece1724/project/metrics/scalability_flink/nexmark_scalability_10p_q14_n0/nfs/flink/nexmark/scalability/q14/p1
# [FILE] Processing: part-094205b0-cc88-4f89-a491-347d5cfa02c3-0-0
#     -> parsed rows: 852310 | bad rows: 0
# [FILE] Processing: part-094205b0-cc88-4f89-a491-347d5cfa02c3-0-1
#     -> parsed rows: 871878 | bad rows: 0
# [FILE] Processing: part-094205b0-cc88-4f89-a491-347d5cfa02c3-0-2
#     -> parsed rows: 869041 | bad rows: 0
# [FILE] Processing: part-094205b0-cc88-4f89-a491-347d5cfa02c3-0-3
#     -> parsed rows: 869062 | bad rows: 0
# [FILE] Processing: part-094205b0-cc88-4f89-a491-347d5cfa02c3-0-4
#     -> parsed rows: 869129 | bad rows: 0
# [FILE] Processing: part-094205b0-cc88-4f89-a491-347d5cfa02c3-0-5
#     -> parsed rows: 863524 | bad rows: 0
# [FILE] Processing: part-094205b0-cc88-4f89-a491-347d5cfa02c3-0-6
#     -> parsed rows: 863485 | bad rows: 0
# [FILE] Processing: part-094205b0-cc88-4f89-a491-347d5cfa02c3-0-7
#     -> parsed rows: 107751 | bad rows: 0
# [TP] n0 p1: 146953.00
# [DATA] p4 → /Users/mdtahsinsharif/Desktop/Tahsin/Tahsin/tahsinTransferred/tahsinNewLaptop/studies/ece1724/project/metrics/scalability_flink/nexmark_scalability_10p_q14_n0/nfs/flink/nexmark/scalability/q14/p4
# [FILE] Processing: part-965adc29-d9af-4906-a95e-e368c6a7bfe1-0-0
#     -> parsed rows: 878431 | bad rows: 0
# [FILE] Processing: part-965adc29-d9af-4906-a95e-e368c6a7bfe1-0-1
#     -> parsed rows: 871669 | bad rows: 0
# [FILE] Processing: part-965adc29-d9af-4906-a95e-e368c6a7bfe1-0-2
#     -> parsed rows: 868960 | bad rows: 0
# [FILE] Processing: part-965adc29-d9af-4906-a95e-e368c6a7bfe1-0-3
#     -> parsed rows: 554297 | bad rows: 0
# [FILE] Processing: part-965adc29-d9af-4906-a95e-e368c6a7bfe1-1-0
#     -> parsed rows: 852451 | bad rows: 0
# [FILE] Processing: part-965adc29-d9af-4906-a95e-e368c6a7bfe1-1-1
#     -> parsed rows: 852567 | bad rows: 0
# [FILE] Processing: part-965adc29-d9af-4906-a95e-e368c6a7bfe1-1-2
#     -> parsed rows: 852490 | bad rows: 0
# [FILE] Processing: part-965adc29-d9af-4906-a95e-e368c6a7bfe1-1-3
#     -> parsed rows: 625568 | bad rows: 0
# [FILE] Processing: part-965adc29-d9af-4906-a95e-e368c6a7bfe1-2-0
#     -> parsed rows: 852533 | bad rows: 0
# [FILE] Processing: part-965adc29-d9af-4906-a95e-e368c6a7bfe1-2-1
#     -> parsed rows: 852513 | bad rows: 0
# [FILE] Processing: part-965adc29-d9af-4906-a95e-e368c6a7bfe1-2-2
#     -> parsed rows: 852522 | bad rows: 0
# [FILE] Processing: part-965adc29-d9af-4906-a95e-e368c6a7bfe1-2-3
#     -> parsed rows: 400633 | bad rows: 0
# [TP] n0 p4: 465710.75
# [DATA] p10 → /Users/mdtahsinsharif/Desktop/Tahsin/Tahsin/tahsinTransferred/tahsinNewLaptop/studies/ece1724/project/metrics/scalability_flink/nexmark_scalability_10p_q14_n0/nfs/flink/nexmark/scalability/q14/p10
# [FILE] Processing: part-16be9186-7a1a-44f2-8e19-c7036320789f-0-0
#     -> parsed rows: 857931 | bad rows: 0
# [FILE] Processing: part-16be9186-7a1a-44f2-8e19-c7036320789f-0-1
#     -> parsed rows: 857908 | bad rows: 0
# [FILE] Processing: part-16be9186-7a1a-44f2-8e19-c7036320789f-0-2
#     -> parsed rows: 270940 | bad rows: 0
# [FILE] Processing: part-16be9186-7a1a-44f2-8e19-c7036320789f-3-0
#     -> parsed rows: 852536 | bad rows: 0
# [FILE] Processing: part-16be9186-7a1a-44f2-8e19-c7036320789f-3-1
#     -> parsed rows: 852494 | bad rows: 0
# [FILE] Processing: part-16be9186-7a1a-44f2-8e19-c7036320789f-3-2
#     -> parsed rows: 265399 | bad rows: 0
# [FILE] Processing: part-16be9186-7a1a-44f2-8e19-c7036320789f-4-0
#     -> parsed rows: 852435 | bad rows: 0
# [FILE] Processing: part-16be9186-7a1a-44f2-8e19-c7036320789f-4-1
#     -> parsed rows: 852544 | bad rows: 0
# [FILE] Processing: part-16be9186-7a1a-44f2-8e19-c7036320789f-4-2
#     -> parsed rows: 273945 | bad rows: 0
# [FILE] Processing: part-16be9186-7a1a-44f2-8e19-c7036320789f-7-0
#     -> parsed rows: 852578 | bad rows: 0
# [FILE] Processing: part-16be9186-7a1a-44f2-8e19-c7036320789f-7-1
#     -> parsed rows: 852526 | bad rows: 0
# [FILE] Processing: part-16be9186-7a1a-44f2-8e19-c7036320789f-7-2
#     -> parsed rows: 229748 | bad rows: 0
# [TP] n0 p10: 517015.17
# [DATA] p20 → /Users/mdtahsinsharif/Desktop/Tahsin/Tahsin/tahsinTransferred/tahsinNewLaptop/studies/ece1724/project/metrics/scalability_flink/nexmark_scalability_10p_q14_n0/nfs/flink/nexmark/scalability/q14/p20
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-1-0
#     -> parsed rows: 852482 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-1-1
#     -> parsed rows: 348966 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-11-0
#     -> parsed rows: 858001 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-11-1
#     -> parsed rows: 471155 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-12-0
#     -> parsed rows: 852459 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-12-1
#     -> parsed rows: 400216 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-13-0
#     -> parsed rows: 857952 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-13-1
#     -> parsed rows: 367990 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-14-0
#     -> parsed rows: 852577 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-14-1
#     -> parsed rows: 356503 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-16-0
#     -> parsed rows: 878384 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-16-1
#     -> parsed rows: 371261 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-17-0
#     -> parsed rows: 852544 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-17-1
#     -> parsed rows: 359140 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-18-0
#     -> parsed rows: 852439 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-18-1
#     -> parsed rows: 373966 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-4-0
#     -> parsed rows: 852622 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-4-1
#     -> parsed rows: 379202 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-5-0
#     -> parsed rows: 852490 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-5-1
#     -> parsed rows: 369075 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-6-0
#     -> parsed rows: 852532 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-6-1
#     -> parsed rows: 482052 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-7-0
#     -> parsed rows: 857941 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-7-1
#     -> parsed rows: 357287 | bad rows: 0
# [TP] n0 p20: 1592855.62
# [DATA] p30 → /Users/mdtahsinsharif/Desktop/Tahsin/Tahsin/tahsinTransferred/tahsinNewLaptop/studies/ece1724/project/metrics/scalability_flink/nexmark_scalability_10p_q14_n0/nfs/flink/nexmark/scalability/q14/p30
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-1-0
#     -> parsed rows: 852469 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-1-1
#     -> parsed rows: 852478 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-1-2
#     -> parsed rows: 112833 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-11-0
#     -> parsed rows: 852510 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-11-1
#     -> parsed rows: 852532 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-11-2
#     -> parsed rows: 6085 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-13-0
#     -> parsed rows: 852463 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-13-1
#     -> parsed rows: 852507 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-13-2
#     -> parsed rows: 149557 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-14-0
#     -> parsed rows: 857984 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-14-1
#     -> parsed rows: 857905 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-14-2
#     -> parsed rows: 70794 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-15-0
#     -> parsed rows: 857945 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-15-1
#     -> parsed rows: 857980 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-15-2
#     -> parsed rows: 127222 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-16-0
#     -> parsed rows: 852531 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-16-1
#     -> parsed rows: 852474 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-16-2
#     -> parsed rows: 138326 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-17-0
#     -> parsed rows: 857969 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-17-1
#     -> parsed rows: 857907 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-17-2
#     -> parsed rows: 1693 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-20-0
#     -> parsed rows: 852403 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-20-1
#     -> parsed rows: 852506 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-20-2
#     -> parsed rows: 44804 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-22-0
#     -> parsed rows: 852468 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-22-1
#     -> parsed rows: 814207 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-4-0
#     -> parsed rows: 852516 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-4-1
#     -> parsed rows: 852506 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-4-2
#     -> parsed rows: 59562 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-5-0
#     -> parsed rows: 863436 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-5-1
#     -> parsed rows: 863487 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-5-2
#     -> parsed rows: 123992 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-6-0
#     -> parsed rows: 852480 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-6-1
#     -> parsed rows: 852414 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-6-2
#     -> parsed rows: 182702 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-7-0
#     -> parsed rows: 852465 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-7-1
#     -> parsed rows: 852458 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-7-2
#     -> parsed rows: 81723 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-9-0
#     -> parsed rows: 863434 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-9-1
#     -> parsed rows: 863539 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-9-2
#     -> parsed rows: 146109 | bad rows: 0
# [TP] n0 p30: 1661735.46
#
# ========================================
# [RUN] nexmark_scalability_10p_q14_n1
# [NODE] n1
# [DATA] p1 → /Users/mdtahsinsharif/Desktop/Tahsin/Tahsin/tahsinTransferred/tahsinNewLaptop/studies/ece1724/project/metrics/scalability_flink/nexmark_scalability_10p_q14_n1/nfs/flink/nexmark/scalability/q14/p1
# [WARN] Missing path
# [DATA] p4 → /Users/mdtahsinsharif/Desktop/Tahsin/Tahsin/tahsinTransferred/tahsinNewLaptop/studies/ece1724/project/metrics/scalability_flink/nexmark_scalability_10p_q14_n1/nfs/flink/nexmark/scalability/q14/p4
# [FILE] Processing: part-965adc29-d9af-4906-a95e-e368c6a7bfe1-3-0
#     -> parsed rows: 857879 | bad rows: 0
# [FILE] Processing: part-965adc29-d9af-4906-a95e-e368c6a7bfe1-3-1
#     -> parsed rows: 857968 | bad rows: 0
# [FILE] Processing: part-965adc29-d9af-4906-a95e-e368c6a7bfe1-3-2
#     -> parsed rows: 857976 | bad rows: 0
# [FILE] Processing: part-965adc29-d9af-4906-a95e-e368c6a7bfe1-3-3
#     -> parsed rows: 730234 | bad rows: 0
# [TP] n1 p4: 164768.38
# [DATA] p10 → /Users/mdtahsinsharif/Desktop/Tahsin/Tahsin/tahsinTransferred/tahsinNewLaptop/studies/ece1724/project/metrics/scalability_flink/nexmark_scalability_10p_q14_n1/nfs/flink/nexmark/scalability/q14/p10
# [FILE] Processing: part-16be9186-7a1a-44f2-8e19-c7036320789f-1-0
#     -> parsed rows: 878425 | bad rows: 0
# [FILE] Processing: part-16be9186-7a1a-44f2-8e19-c7036320789f-1-1
#     -> parsed rows: 871753 | bad rows: 0
# [FILE] Processing: part-16be9186-7a1a-44f2-8e19-c7036320789f-1-2
#     -> parsed rows: 289166 | bad rows: 0
# [FILE] Processing: part-16be9186-7a1a-44f2-8e19-c7036320789f-2-0
#     -> parsed rows: 857991 | bad rows: 0
# [FILE] Processing: part-16be9186-7a1a-44f2-8e19-c7036320789f-2-1
#     -> parsed rows: 857943 | bad rows: 0
# [FILE] Processing: part-16be9186-7a1a-44f2-8e19-c7036320789f-2-2
#     -> parsed rows: 312082 | bad rows: 0
# [FILE] Processing: part-16be9186-7a1a-44f2-8e19-c7036320789f-5-0
#     -> parsed rows: 857908 | bad rows: 0
# [FILE] Processing: part-16be9186-7a1a-44f2-8e19-c7036320789f-5-1
#     -> parsed rows: 857939 | bad rows: 0
# [FILE] Processing: part-16be9186-7a1a-44f2-8e19-c7036320789f-5-2
#     -> parsed rows: 272490 | bad rows: 0
# [FILE] Processing: part-16be9186-7a1a-44f2-8e19-c7036320789f-6-0
#     -> parsed rows: 852490 | bad rows: 0
# [FILE] Processing: part-16be9186-7a1a-44f2-8e19-c7036320789f-6-1
#     -> parsed rows: 852447 | bad rows: 0
# [FILE] Processing: part-16be9186-7a1a-44f2-8e19-c7036320789f-6-2
#     -> parsed rows: 250056 | bad rows: 0
# [FILE] Processing: part-16be9186-7a1a-44f2-8e19-c7036320789f-8-0
#     -> parsed rows: 852516 | bad rows: 0
# [FILE] Processing: part-16be9186-7a1a-44f2-8e19-c7036320789f-8-1
#     -> parsed rows: 852531 | bad rows: 0
# [FILE] Processing: part-16be9186-7a1a-44f2-8e19-c7036320789f-8-2
#     -> parsed rows: 313172 | bad rows: 0
# [FILE] Processing: part-16be9186-7a1a-44f2-8e19-c7036320789f-9-0
#     -> parsed rows: 852515 | bad rows: 0
# [FILE] Processing: part-16be9186-7a1a-44f2-8e19-c7036320789f-9-1
#     -> parsed rows: 852557 | bad rows: 0
# [FILE] Processing: part-16be9186-7a1a-44f2-8e19-c7036320789f-9-2
#     -> parsed rows: 299220 | bad rows: 0
# [TP] n1 p10: 789967.58
# [DATA] p20 → /Users/mdtahsinsharif/Desktop/Tahsin/Tahsin/tahsinTransferred/tahsinNewLaptop/studies/ece1724/project/metrics/scalability_flink/nexmark_scalability_10p_q14_n1/nfs/flink/nexmark/scalability/q14/p20
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-0-0
#     -> parsed rows: 852459 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-0-1
#     -> parsed rows: 465570 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-10-0
#     -> parsed rows: 857956 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-10-1
#     -> parsed rows: 417370 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-15-0
#     -> parsed rows: 863354 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-15-1
#     -> parsed rows: 449339 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-19-0
#     -> parsed rows: 852447 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-19-1
#     -> parsed rows: 490457 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-2-0
#     -> parsed rows: 852553 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-2-1
#     -> parsed rows: 442950 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-3-0
#     -> parsed rows: 852499 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-3-1
#     -> parsed rows: 482173 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-8-0
#     -> parsed rows: 857885 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-8-1
#     -> parsed rows: 422388 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-9-0
#     -> parsed rows: 852535 | bad rows: 0
# [FILE] Processing: part-3bd0afab-40bd-4115-a0bf-47838efcfd7d-9-1
#     -> parsed rows: 412584 | bad rows: 0
# [TP] n1 p20: 1100679.62
# [DATA] p30 → /Users/mdtahsinsharif/Desktop/Tahsin/Tahsin/tahsinTransferred/tahsinNewLaptop/studies/ece1724/project/metrics/scalability_flink/nexmark_scalability_10p_q14_n1/nfs/flink/nexmark/scalability/q14/p30
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-0-0
#     -> parsed rows: 878516 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-0-1
#     -> parsed rows: 626141 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-10-0
#     -> parsed rows: 852536 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-10-1
#     -> parsed rows: 678898 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-12-0
#     -> parsed rows: 858007 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-12-1
#     -> parsed rows: 857958 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-12-2
#     -> parsed rows: 178884 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-18-0
#     -> parsed rows: 852479 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-18-1
#     -> parsed rows: 623491 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-19-0
#     -> parsed rows: 852437 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-19-1
#     -> parsed rows: 737377 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-2-0
#     -> parsed rows: 858025 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-2-1
#     -> parsed rows: 715118 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-21-0
#     -> parsed rows: 857951 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-21-1
#     -> parsed rows: 857895 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-21-2
#     -> parsed rows: 52076 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-23-0
#     -> parsed rows: 852504 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-23-1
#     -> parsed rows: 658957 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-24-0
#     -> parsed rows: 857888 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-24-1
#     -> parsed rows: 588614 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-25-0
#     -> parsed rows: 852463 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-25-1
#     -> parsed rows: 712257 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-26-0
#     -> parsed rows: 852464 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-26-1
#     -> parsed rows: 626179 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-27-0
#     -> parsed rows: 852441 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-27-1
#     -> parsed rows: 785100 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-28-0
#     -> parsed rows: 852408 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-28-1
#     -> parsed rows: 811902 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-29-0
#     -> parsed rows: 852517 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-29-1
#     -> parsed rows: 674324 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-3-0
#     -> parsed rows: 852499 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-3-1
#     -> parsed rows: 852507 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-3-2
#     -> parsed rows: 1 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-8-0
#     -> parsed rows: 852411 | bad rows: 0
# [FILE] Processing: part-2c4ab67a-56b8-479c-808a-bdee869bae46-8-1
#     -> parsed rows: 592199 | bad rows: 0
# [TP] n1 p30: 1682344.38
#
# ================ LATENCY SUMMARY ================
#
# [n0]
#   Avg latency : 19971.97 ms
#   P50 latency : 20023.00 ms
#   P95 latency : 34320.00 ms
#   P99 latency : 35591.00 ms
#
# [n1]
#   Avg latency : 19604.77 ms
#   P50 latency : 19696.00 ms
#   P95 latency : 33688.00 ms
#   P99 latency : 35015.00 ms

# %%
# ===================== PLOTTING =====================
node_colors = {"n0": "blue", "n1": "orange"}

# ---- Latency ----
print("[PLOT] Latency...")
plt.figure()

for node, df in node_data.items():
    lat = compute_latency(df)

    plt.plot(smooth(lat["p50"]), label=f"{node} p50", color=node_colors.get(node))
    plt.plot(smooth(lat["p95"]), "--", label=f"{node} p95", color=node_colors.get(node))
    plt.plot(smooth(lat["p99"]), ":", label=f"{node} p99", color=node_colors.get(node))
# Out:
# [PLOT] Latency...

# %%
print("[PLOT] Throughput (time)...")
plt.figure()

all_failures = []

# ---- per-node + cluster aggregation ----
cluster_tp = None

for node, df in node_data.items():
    tp = compute_throughput(df)
    tp_s = smooth(tp)

    # per-node line
    plt.plot(tp_s, label=node, color=node_colors.get(node))

    # initialize cluster series
    if cluster_tp is None:
        cluster_tp = tp.copy()
    else:
        cluster_tp = cluster_tp.add(tp, fill_value=0)

    gaps = detect_failures(tp)
    for start, end in gaps:
        all_failures.append((start, end, node))

# ---- cluster throughput line ----
if cluster_tp is not None:
    cluster_tp_s = smooth(cluster_tp)
    plt.plot(cluster_tp_s, label="cluster (n0+n1)", color="black", linewidth=2)

# ---- highlight failures ----
for start, end, node in all_failures:
    plt.axvspan(start, end, alpha=0.15, color=node_colors.get(node))

plt.title(f"Throughput ({query})")
plt.xlabel("Time")
plt.ylabel("events/sec")
handles, labels = plt.gca().get_legend_handles_labels()
if labels:
    plt.legend()
else:
    print("[WARN] No data plotted → skipping legend")
plt.tight_layout()
plt.savefig(output_dir / f"throughput_{query}.png")
plt.close()
# Out:
# [PLOT] Throughput (time)...

# %%
node_data
# Out:
# {'n0':                           auction   bidder       bidder2  timeofday  \
#  processed_time
#  2026-04-13 03:33:45.361   6001000  2002001  4.861612e+06  nightTime
#  2026-04-13 03:33:45.363   6000963  2002001  7.625776e+06  nightTime
#  2026-04-13 03:33:45.363   6000946  2001492  3.401122e+07  nightTime
#  2026-04-13 03:33:45.363   6000967  2002001  6.122362e+06  nightTime
#  2026-04-13 03:33:45.363   6001000  2002001  1.213115e+07  nightTime
#  ...                           ...      ...           ...        ...
#  2026-04-13 03:34:55.043  12446557  4149945  5.566596e+06  nightTime
#  2026-04-13 03:34:55.043   6459100  2154701  2.822754e+07  nightTime
#  2026-04-13 03:34:55.043   6459052  2154048  4.569072e+06  nightTime
#  2026-04-13 03:34:55.043   6459056  2154701  3.108144e+06  nightTime
#  2026-04-13 03:34:55.043  12446600  4150501  9.455178e+06  nightTime
#
#                                       event_time  \
#  processed_time
#  2026-04-13 03:33:45.361 2026-04-13 03:33:41.359
#  2026-04-13 03:33:45.363 2026-04-13 03:33:41.359
#  2026-04-13 03:33:45.363 2026-04-13 03:33:41.359
#  2026-04-13 03:33:45.363 2026-04-13 03:33:41.359
#  2026-04-13 03:33:45.363 2026-04-13 03:33:41.359
#  ...                                         ...
#  2026-04-13 03:34:55.043 2026-04-13 03:34:18.492
#  2026-04-13 03:34:55.043 2026-04-13 03:34:19.536
#  2026-04-13 03:34:55.043 2026-04-13 03:34:19.536
#  2026-04-13 03:34:55.043 2026-04-13 03:34:19.536
#  2026-04-13 03:34:55.043 2026-04-13 03:34:18.492
#
#                                                                       extra  \
#  processed_time
#  2026-04-13 03:33:45.361  kiefpfLU\\NJ]aT[MHaldlkjzmmqvi[KMQY]wrlujeunja...
#  2026-04-13 03:33:45.363  puttcdrjzvjlwakiwgrucyoH[Y[\]aY`Q\QjzzkluXIJZZ...
#  2026-04-13 03:33:45.363  evpfgllvgnaffvdtjmzkqckaSI`ONH`SWTZIodebgvIRLK...
#  2026-04-13 03:33:45.363  [_]NK[ITaZiridprrhgguiucuwwrX[UWVR`LOW^Wdbuexj...
#  2026-04-13 03:33:45.363  K[S^WV`QWYNNpeuacz^MSRJW]LaJR_TVP`OLPZNLM[xmhu...
#  ...                                                                    ...
#  2026-04-13 03:34:55.043  [M_YpgmxbgQZ[KLUdpgvmwdhmhciWH_PVPxqmqudhiljej...
#  2026-04-13 03:34:55.043  [HU^uioqyqTYPMVJgrdjtqfsrolfuvvjjmnalubkewvran...
#  2026-04-13 03:34:55.043  \PzpavgfmyqvkoVYH[\ROWU^JT`NS`aVXVP^HQihkwgaRQ...
#  2026-04-13 03:34:55.043  KNxxsdyoktahpl_Z]TI\hlpclr[QP`\UP`WKHOjrzlbxQV...
#  2026-04-13 03:34:55.043  zhiqdrtozmjgqteddgHZL]VHsyfwbikzyewf_H``TLMJSO...
#
#                           booleannumber  latency_ms
#  processed_time
#  2026-04-13 03:33:45.361              0      4002.0
#  2026-04-13 03:33:45.363              2      4004.0
#  2026-04-13 03:33:45.363              1      4004.0
#  2026-04-13 03:33:45.363              1      4004.0
#  2026-04-13 03:33:45.363              2      4004.0
#  ...                                ...         ...
#  2026-04-13 03:34:55.043              1     36551.0
#  2026-04-13 03:34:55.043              1     35507.0
#  2026-04-13 03:34:55.043              0     35507.0
#  2026-04-13 03:34:55.043              1     35507.0
#  2026-04-13 03:34:55.043              1     36551.0
#
#  [7855180 rows x 8 columns],
#  'n1':                           auction   bidder       bidder2  timeofday  \
#  processed_time
#  2026-04-13 03:33:45.323      1002     2002  5.403570e+06  nightTime
#  2026-04-13 03:33:45.325      1000     2004  1.145970e+06  nightTime
#  2026-04-13 03:33:45.325      1003     2001  4.302465e+07  nightTime
#  2026-04-13 03:33:45.325      1000     2000  3.342110e+07  nightTime
#  2026-04-13 03:33:45.325      1007     2009  9.030387e+06  nightTime
#  ...                           ...      ...           ...        ...
#  2026-04-13 03:34:55.044   9467664  3156828  3.668250e+07  nightTime
#  2026-04-13 03:34:55.044   9467587  3157501  3.161354e+07  nightTime
#  2026-04-13 03:34:55.044   9467600  3157501  6.796701e+06  nightTime
#  2026-04-13 03:34:55.044   3458631  1154501  1.545944e+06  nightTime
#  2026-04-13 03:34:55.044  24462077  8154814  6.988574e+06  nightTime
#
#                                       event_time  \
#  processed_time
#  2026-04-13 03:33:45.323 2026-04-13 03:33:41.359
#  2026-04-13 03:33:45.325 2026-04-13 03:33:41.359
#  2026-04-13 03:33:45.325 2026-04-13 03:33:41.359
#  2026-04-13 03:33:45.325 2026-04-13 03:33:41.359
#  2026-04-13 03:33:45.325 2026-04-13 03:33:41.359
#  ...                                         ...
#  2026-04-13 03:34:55.044 2026-04-13 03:34:20.247
#  2026-04-13 03:34:55.044 2026-04-13 03:34:20.247
#  2026-04-13 03:34:55.044 2026-04-13 03:34:20.247
#  2026-04-13 03:34:55.044 2026-04-13 03:34:19.500
#  2026-04-13 03:34:55.044 2026-04-13 03:34:19.789
#
#                                                                       extra  \
#  processed_time
#  2026-04-13 03:33:45.323  J`_MJOcvuricSMZMXVwuxbvgHZTYV_vbzmxlR[]SOOYSJK...
#  2026-04-13 03:33:45.325  dtxMPHIKS`VLR[UJXVJT[aztkcqHITUUHRO]RYIhvqqyy[...
#  2026-04-13 03:33:45.325  ZZ]QIXLRJRSHW[[UX[UTMQKZKajtqhzecyeos[]`ITSiby...
#  2026-04-13 03:33:45.325  ^JaI`]\P[_HMQKdpdtijQPP\aKMXUVJOrhfdabQJ`N\UZ^...
#  2026-04-13 03:33:45.325  dvvnqzlyzlsdruuth\^`_PHNPWTOZzzbfnkpaqyuiVaJY]...
#  ...                                                                    ...
#  2026-04-13 03:34:55.044  TRXHXOWMXfvnzlqK^STVJiqxnghY`TI\LnqijyeN\[T\Kw...
#  2026-04-13 03:34:55.044  ^LJXaYochmjq]U]PLPsohddedekeupratrpr\HLHIPyvkh...
#  2026-04-13 03:34:55.044  lxixszqbfeMZQV\VRLLXHVQWWNJHweuqoeX_W_WKolewrd...
#  2026-04-13 03:34:55.044  _J]JV[LHJRSQqkwwkofpshkoN]OUMYQ]QVZUswlvlwH]]T...
#  2026-04-13 03:34:55.044  ZY\Itwplxr`LHK^UIQXI^UHZ`ZOajqippoSNYN[LWN_ISV...
#
#                           booleannumber  latency_ms
#  processed_time
#  2026-04-13 03:33:45.323              2      3964.0
#  2026-04-13 03:33:45.325              2      3966.0
#  2026-04-13 03:33:45.325              2      3966.0
#  2026-04-13 03:33:45.325              0      3966.0
#  2026-04-13 03:33:45.325              0      3966.0
#  ...                                ...         ...
#  2026-04-13 03:34:55.044              0     34797.0
#  2026-04-13 03:34:55.044              1     34797.0
#  2026-04-13 03:34:55.044              0     34797.0
#  2026-04-13 03:34:55.044              0     35544.0
#  2026-04-13 03:34:55.044              1     35255.0
#
#  [12009125 rows x 8 columns]}

# %%
print("[PLOT] Throughput vs cores...")
plt.figure()

core_values = [int(c.replace("p", "")) for c in cores_list]

# ---- per-node curves ----
for node, core_map in throughput_summary.items():
    y = []
    x = []

    for c in cores_list:
        if c in core_map:
            x.append(int(c.replace("p", "")))
            y.append(core_map[c])

    if len(y) > 0:
        plt.plot(x, y, marker="o", label=node)

# ---- cluster aggregation ----
cluster_curve = []

for c in cores_list:
    total = 0
    count = 0

    for node, core_map in throughput_summary.items():
        if c in core_map:
            total += core_map[c]
            count += 1

    if count > 0:
        cluster_curve.append(total)
    else:
        cluster_curve.append(None)

# clean missing points
x_clean = []
y_clean = []

for x, y in zip(core_values, cluster_curve):
    if y is not None:
        x_clean.append(x)
        y_clean.append(y)

plt.plot(x_clean, y_clean, marker="o", linewidth=3, color="black", label="cluster (n0+n1)")

plt.title(f"Throughput vs Cores ({query})")
plt.xlabel("Number of Cores")
plt.ylabel("Events/sec")
plt.grid(True, linestyle="--", alpha=0.5)
handles, labels = plt.gca().get_legend_handles_labels()
if labels:
    plt.legend()
else:
    print("[WARN] No data plotted → skipping legend")
plt.tight_layout()

plt.savefig(output_dir / f"throughput_vs_cores_{query}.png")
plt.close()
# Out:
# [PLOT] Throughput vs cores...
