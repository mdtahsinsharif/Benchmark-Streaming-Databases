# %%
import sys
print(sys.executable)
# Out:
# /Users/mdtahsinsharif/anaconda3/envs/stream-metrics/bin/python

# %%
import os
import tarfile
import shutil
import glob
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# %%
# ===================== CONFIG =====================
query = "q2"
failure = "scalability"
cores_list = ["p1", "p4", "p10", "p20", "p30"]
#base_dir = Path(failure + "_flink")
base_dir = Path.cwd()
output_dir = Path("analysis_output") / failure / query
window_seconds = 5
# ==================================================

# %%
output_dir.mkdir(parents=True, exist_ok=True)

print("[START] Analysis pipeline starting...")
print(f"Query: {query}")
print(f"Base dir: {base_dir}")
print(f"Output dir: {output_dir}")

pattern = f"nexmark_{failure}_10p_{query}_*"
run_dirs = sorted([p for p in base_dir.glob(pattern) if p.is_dir()])

print(f"[INFO] Found {len(run_dirs)} run directories")

if not run_dirs:
    print(f"No runs found for {query}")
    exit(1)

node_data = {}
throughput_summary = {}  # {node: {cores: throughput}}
cluster_throughput = {}
# Out:
# [START] Analysis pipeline starting...
# Query: q2
# Base dir: /Users/mdtahsinsharif/Desktop/Tahsin/Tahsin/tahsinTransferred/tahsinNewLaptop/studies/ece1724/project/metrics/scalability_flink
# Output dir: analysis_output/scalability/q2
# [INFO] Found 2 run directories

# %%
# ===================== HELPERS =====================
def compute_latency_summary(df):
    return {
        "avg": df["latency_ms"].mean(),
        "p50": df["latency_ms"].quantile(0.50),
        "p95": df["latency_ms"].quantile(0.95),
        "p99": df["latency_ms"].quantile(0.99),
    }

def compute_latency(df):
    r = df["latency_ms"].resample(f"{window_seconds}s")
    return pd.DataFrame({
        "p50": r.quantile(0.5),
        "p95": r.quantile(0.95),
        "p99": r.quantile(0.99),
    })

def compute_throughput(df):
    return df["auction"].resample(f"{window_seconds}s").size()

def smooth(series, w=5):
    return series.rolling(w, min_periods=1).mean()

def detect_failures(tp):
    gaps = []
    start = None

    for ts, v in tp.items():
        if v == 0 and start is None:
            start = ts
        elif v > 0 and start is not None:
            gaps.append((start, ts))
            start = None

    return gaps

# %%
def parse_part_file(pf):
    rows = []
    bad = 0

    print(f"[FILE] Processing: {os.path.basename(pf)}")

    with open(pf, "r", errors="ignore") as f:
        for line_num, line in enumerate(f, 1):
            parts = line.rstrip("\n").split(",")

            if len(parts) < 4:
                bad += 1
                continue

            auction, price, event_time, processed_time= parts

            try:
                rows.append({
                    "auction": int(auction),
                    "price": float(price),
                    "event_time": event_time,
                    "processed_time": processed_time
                })
            except:
                bad += 1

    print(f"    -> parsed rows: {len(rows)} | bad rows: {bad}")
    return pd.DataFrame(rows)

# %%
# ===================== MAIN LOOP =====================
for run_dir in run_dirs:
    tar_name = run_dir.name
    node = tar_name.split("_")[-1]

    print("\n========================================")
    print(f"[RUN] {tar_name}")
    print(f"[NODE] {node}")

    for cores in cores_list:
        data_path = run_dir / "nfs" / "flink" / "nexmark" / failure / query / cores

        print(f"[DATA] {cores} → {data_path}")

        if not data_path.exists():
            print(f"[WARN] Missing path")
            continue

        part_files = sorted(
            glob.glob(str(data_path / "**" / "part-*"), recursive=True)
        )

        if not part_files:
            print(f"[WARN] No part files")
            continue

        dfs = []
        for pf in part_files:
            df_part = parse_part_file(pf)
            if not df_part.empty:
                dfs.append(df_part)

        if not dfs:
            continue

        df = pd.concat(dfs, ignore_index=True)

        # ---- timestamps ----
        df["event_time"] = pd.to_datetime(df["event_time"], errors="coerce")
        df["processed_time"] = pd.to_datetime(df["processed_time"], errors="coerce")

        df = df.dropna(subset=["event_time", "processed_time"])

        df["processed_time"] += pd.Timedelta(hours=4)

        # ---- latency ----
        df["latency_ms"] = (
            (df["processed_time"] - df["event_time"])
            .dt.total_seconds() * 1000
        )

        df = df.sort_values("processed_time").set_index("processed_time")

        # store only one core (for time-series plots)
        if cores == "p10":
            node_data[node] = df

        # ---- throughput summary ----
        tp = compute_throughput(df)

        # steady-state avg (ignore first 20%)
        tp_ss = tp[int(len(tp)*0.2):]
        avg_tp = tp_ss.mean() if not tp_ss.empty else tp.mean()

        throughput_summary.setdefault(node, {})[cores] = avg_tp

        print(f"[TP] {node} {cores}: {avg_tp:.2f}")

# ===================== LATENCY SUMMARY =====================
print("\n================ LATENCY SUMMARY ================\n")

for node, df in node_data.items():
    stats = compute_latency_summary(df)

    print(f"[{node}]")
    print(f"  Avg latency : {stats['avg']:.2f} ms")
    print(f"  P50 latency : {stats['p50']:.2f} ms")
    print(f"  P95 latency : {stats['p95']:.2f} ms")
    print(f"  P99 latency : {stats['p99']:.2f} ms")
    print()
# Out:
# ========================================
# [RUN] nexmark_scalability_10p_q2_n0
# [NODE] n0
# [DATA] p1 → /Users/mdtahsinsharif/Desktop/Tahsin/Tahsin/tahsinTransferred/tahsinNewLaptop/studies/ece1724/project/metrics/scalability_flink/nexmark_scalability_10p_q2_n0/nfs/flink/nexmark/scalability/q2/p1
# [FILE] Processing: part-026aaf35-f094-48ab-8f0a-1e6400dd7eb3-0-0
#     -> parsed rows: 66980 | bad rows: 0
# [TP] n0 p1: 8655.86
# [DATA] p4 → /Users/mdtahsinsharif/Desktop/Tahsin/Tahsin/tahsinTransferred/tahsinNewLaptop/studies/ece1724/project/metrics/scalability_flink/nexmark_scalability_10p_q2_n0/nfs/flink/nexmark/scalability/q2/p4
# [FILE] Processing: part-b729d05a-9d5a-4633-8d99-40a03fdbe586-1-0
#     -> parsed rows: 26293 | bad rows: 0
# [FILE] Processing: part-b729d05a-9d5a-4633-8d99-40a03fdbe586-2-0
#     -> parsed rows: 26480 | bad rows: 0
# [FILE] Processing: part-b729d05a-9d5a-4633-8d99-40a03fdbe586-3-0
#     -> parsed rows: 26419 | bad rows: 0
# [TP] n0 p4: 19767.25
# [DATA] p10 → /Users/mdtahsinsharif/Desktop/Tahsin/Tahsin/tahsinTransferred/tahsinNewLaptop/studies/ece1724/project/metrics/scalability_flink/nexmark_scalability_10p_q2_n0/nfs/flink/nexmark/scalability/q2/p10
# [FILE] Processing: part-59572412-f0c3-41ad-b3cd-9c874ef73b66-0-0
#     -> parsed rows: 161096 | bad rows: 0
# [FILE] Processing: part-59572412-f0c3-41ad-b3cd-9c874ef73b66-2-0
#     -> parsed rows: 162727 | bad rows: 0
# [FILE] Processing: part-59572412-f0c3-41ad-b3cd-9c874ef73b66-4-0
#     -> parsed rows: 162202 | bad rows: 0
# [FILE] Processing: part-59572412-f0c3-41ad-b3cd-9c874ef73b66-9-0
#     -> parsed rows: 162089 | bad rows: 0
# [TP] n0 p10: 31864.47
# [DATA] p20 → /Users/mdtahsinsharif/Desktop/Tahsin/Tahsin/tahsinTransferred/tahsinNewLaptop/studies/ece1724/project/metrics/scalability_flink/nexmark_scalability_10p_q2_n0/nfs/flink/nexmark/scalability/q2/p20
# [FILE] Processing: part-2caa78aa-d293-4544-b257-2cfd72b1c567-12-0
#     -> parsed rows: 188625 | bad rows: 0
# [FILE] Processing: part-2caa78aa-d293-4544-b257-2cfd72b1c567-13-0
#     -> parsed rows: 189058 | bad rows: 0
# [FILE] Processing: part-2caa78aa-d293-4544-b257-2cfd72b1c567-14-0
#     -> parsed rows: 188853 | bad rows: 0
# [FILE] Processing: part-2caa78aa-d293-4544-b257-2cfd72b1c567-16-0
#     -> parsed rows: 188099 | bad rows: 0
# [FILE] Processing: part-2caa78aa-d293-4544-b257-2cfd72b1c567-17-0
#     -> parsed rows: 188778 | bad rows: 0
# [FILE] Processing: part-2caa78aa-d293-4544-b257-2cfd72b1c567-18-0
#     -> parsed rows: 189197 | bad rows: 0
# [FILE] Processing: part-2caa78aa-d293-4544-b257-2cfd72b1c567-2-0
#     -> parsed rows: 189215 | bad rows: 0
# [FILE] Processing: part-2caa78aa-d293-4544-b257-2cfd72b1c567-4-0
#     -> parsed rows: 188262 | bad rows: 0
# [FILE] Processing: part-2caa78aa-d293-4544-b257-2cfd72b1c567-5-0
#     -> parsed rows: 189425 | bad rows: 0
# [FILE] Processing: part-2caa78aa-d293-4544-b257-2cfd72b1c567-6-0
#     -> parsed rows: 188534 | bad rows: 0
# [FILE] Processing: part-2caa78aa-d293-4544-b257-2cfd72b1c567-7-0
#     -> parsed rows: 188887 | bad rows: 0
# [FILE] Processing: part-2caa78aa-d293-4544-b257-2cfd72b1c567-8-0
#     -> parsed rows: 189292 | bad rows: 0
# [TP] n0 p20: 89978.90
# [DATA] p30 → /Users/mdtahsinsharif/Desktop/Tahsin/Tahsin/tahsinTransferred/tahsinNewLaptop/studies/ece1724/project/metrics/scalability_flink/nexmark_scalability_10p_q2_n0/nfs/flink/nexmark/scalability/q2/p30
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-1-0
#     -> parsed rows: 67188 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-1-1
#     -> parsed rows: 58379 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-10-0
#     -> parsed rows: 66451 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-10-1
#     -> parsed rows: 58784 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-14-0
#     -> parsed rows: 69466 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-14-1
#     -> parsed rows: 56469 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-15-0
#     -> parsed rows: 67639 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-15-1
#     -> parsed rows: 58950 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-17-0
#     -> parsed rows: 69625 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-17-1
#     -> parsed rows: 55569 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-20-0
#     -> parsed rows: 67934 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-20-1
#     -> parsed rows: 58737 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-22-0
#     -> parsed rows: 74013 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-22-1
#     -> parsed rows: 52739 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-26-0
#     -> parsed rows: 71517 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-26-1
#     -> parsed rows: 54600 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-27-0
#     -> parsed rows: 65684 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-27-1
#     -> parsed rows: 60114 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-28-0
#     -> parsed rows: 72876 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-28-1
#     -> parsed rows: 52822 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-29-0
#     -> parsed rows: 71449 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-29-1
#     -> parsed rows: 54057 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-3-0
#     -> parsed rows: 70417 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-3-1
#     -> parsed rows: 55904 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-6-0
#     -> parsed rows: 65635 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-6-1
#     -> parsed rows: 60416 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-8-0
#     -> parsed rows: 67291 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-8-1
#     -> parsed rows: 58164 | bad rows: 0
# [TP] n0 p30: 88768.19
#
# ========================================
# [RUN] nexmark_scalability_10p_q2_n1
# [NODE] n1
# [DATA] p1 → /Users/mdtahsinsharif/Desktop/Tahsin/Tahsin/tahsinTransferred/tahsinNewLaptop/studies/ece1724/project/metrics/scalability_flink/nexmark_scalability_10p_q2_n1/nfs/flink/nexmark/scalability/q2/p1
# [WARN] Missing path
# [DATA] p4 → /Users/mdtahsinsharif/Desktop/Tahsin/Tahsin/tahsinTransferred/tahsinNewLaptop/studies/ece1724/project/metrics/scalability_flink/nexmark_scalability_10p_q2_n1/nfs/flink/nexmark/scalability/q2/p4
# [FILE] Processing: part-b729d05a-9d5a-4633-8d99-40a03fdbe586-0-0
#     -> parsed rows: 28869 | bad rows: 0
# [TP] n1 p4: 7210.50
# [DATA] p10 → /Users/mdtahsinsharif/Desktop/Tahsin/Tahsin/tahsinTransferred/tahsinNewLaptop/studies/ece1724/project/metrics/scalability_flink/nexmark_scalability_10p_q2_n1/nfs/flink/nexmark/scalability/q2/p10
# [FILE] Processing: part-59572412-f0c3-41ad-b3cd-9c874ef73b66-1-0
#     -> parsed rows: 167157 | bad rows: 0
# [FILE] Processing: part-59572412-f0c3-41ad-b3cd-9c874ef73b66-3-0
#     -> parsed rows: 162769 | bad rows: 0
# [FILE] Processing: part-59572412-f0c3-41ad-b3cd-9c874ef73b66-5-0
#     -> parsed rows: 162144 | bad rows: 0
# [FILE] Processing: part-59572412-f0c3-41ad-b3cd-9c874ef73b66-6-0
#     -> parsed rows: 165261 | bad rows: 0
# [FILE] Processing: part-59572412-f0c3-41ad-b3cd-9c874ef73b66-7-0
#     -> parsed rows: 164522 | bad rows: 0
# [FILE] Processing: part-59572412-f0c3-41ad-b3cd-9c874ef73b66-8-0
#     -> parsed rows: 163624 | bad rows: 0
# [TP] n1 p10: 48555.24
# [DATA] p20 → /Users/mdtahsinsharif/Desktop/Tahsin/Tahsin/tahsinTransferred/tahsinNewLaptop/studies/ece1724/project/metrics/scalability_flink/nexmark_scalability_10p_q2_n1/nfs/flink/nexmark/scalability/q2/p20
# [FILE] Processing: part-2caa78aa-d293-4544-b257-2cfd72b1c567-0-0
#     -> parsed rows: 189045 | bad rows: 0
# [FILE] Processing: part-2caa78aa-d293-4544-b257-2cfd72b1c567-1-0
#     -> parsed rows: 189634 | bad rows: 0
# [FILE] Processing: part-2caa78aa-d293-4544-b257-2cfd72b1c567-10-0
#     -> parsed rows: 188229 | bad rows: 0
# [FILE] Processing: part-2caa78aa-d293-4544-b257-2cfd72b1c567-11-0
#     -> parsed rows: 189225 | bad rows: 0
# [FILE] Processing: part-2caa78aa-d293-4544-b257-2cfd72b1c567-15-0
#     -> parsed rows: 189195 | bad rows: 0
# [FILE] Processing: part-2caa78aa-d293-4544-b257-2cfd72b1c567-19-0
#     -> parsed rows: 188276 | bad rows: 0
# [FILE] Processing: part-2caa78aa-d293-4544-b257-2cfd72b1c567-3-0
#     -> parsed rows: 188253 | bad rows: 0
# [FILE] Processing: part-2caa78aa-d293-4544-b257-2cfd72b1c567-9-0
#     -> parsed rows: 188596 | bad rows: 0
# [TP] n1 p20: 62032.50
# [DATA] p30 → /Users/mdtahsinsharif/Desktop/Tahsin/Tahsin/tahsinTransferred/tahsinNewLaptop/studies/ece1724/project/metrics/scalability_flink/nexmark_scalability_10p_q2_n1/nfs/flink/nexmark/scalability/q2/p30
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-0-0
#     -> parsed rows: 60084 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-0-1
#     -> parsed rows: 65596 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-11-0
#     -> parsed rows: 62833 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-11-1
#     -> parsed rows: 63009 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-12-0
#     -> parsed rows: 57480 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-12-1
#     -> parsed rows: 68192 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-13-0
#     -> parsed rows: 58853 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-13-1
#     -> parsed rows: 66914 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-16-0
#     -> parsed rows: 65861 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-16-1
#     -> parsed rows: 61364 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-18-0
#     -> parsed rows: 57024 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-18-1
#     -> parsed rows: 68971 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-19-0
#     -> parsed rows: 63231 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-19-1
#     -> parsed rows: 63068 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-2-0
#     -> parsed rows: 63309 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-2-1
#     -> parsed rows: 62458 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-21-0
#     -> parsed rows: 63750 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-21-1
#     -> parsed rows: 62001 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-23-0
#     -> parsed rows: 55739 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-23-1
#     -> parsed rows: 70875 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-24-0
#     -> parsed rows: 61176 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-24-1
#     -> parsed rows: 65498 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-25-0
#     -> parsed rows: 62989 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-25-1
#     -> parsed rows: 63870 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-4-0
#     -> parsed rows: 58923 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-4-1
#     -> parsed rows: 66665 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-5-0
#     -> parsed rows: 59978 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-5-1
#     -> parsed rows: 65649 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-7-0
#     -> parsed rows: 60195 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-7-1
#     -> parsed rows: 65386 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-9-0
#     -> parsed rows: 53990 | bad rows: 0
# [FILE] Processing: part-d8c066df-b788-4a4f-9033-0864c1dd3891-9-1
#     -> parsed rows: 71280 | bad rows: 0
# [TP] n1 p30: 92906.44
#
# ================ LATENCY SUMMARY ================
#
# [n0]
#   Avg latency : -1759.33 ms
#   P50 latency : -1760.00 ms
#   P95 latency : 3478.00 ms
#   P99 latency : 3959.00 ms
#
# [n1]
#   Avg latency : -2397.17 ms
#   P50 latency : -2338.00 ms
#   P95 latency : 3471.00 ms
#   P99 latency : 4018.00 ms

# %%
node_data
# Out:
# {'n0':                           auction       price              event_time  \
#  processed_time
#  2026-04-13 03:20:39.597      1107      9982.0 2026-04-13 03:20:35.626
#  2026-04-13 03:20:39.617   6000924    630822.0 2026-04-13 03:20:35.616
#  2026-04-13 03:20:39.627   9001017     25308.0 2026-04-13 03:20:35.618
#  2026-04-13 03:20:39.646   6000924    248139.0 2026-04-13 03:20:35.616
#  2026-04-13 03:20:39.646  15000957      2515.0 2026-04-13 03:20:35.616
#  ...                           ...         ...                     ...
#  2026-04-13 03:22:15.297   1293837  28207884.0 2026-04-13 03:22:23.355
#  2026-04-13 03:22:15.298   1293837  10059969.0 2026-04-13 03:22:23.355
#  2026-04-13 03:22:15.298   1293837  47548803.0 2026-04-13 03:22:23.356
#  2026-04-13 03:22:15.298   1293837      1156.0 2026-04-13 03:22:23.356
#  2026-04-13 03:22:15.298  16287291    132007.0 2026-04-13 03:22:22.807
#
#                           latency_ms
#  processed_time
#  2026-04-13 03:20:39.597      3971.0
#  2026-04-13 03:20:39.617      4001.0
#  2026-04-13 03:20:39.627      4009.0
#  2026-04-13 03:20:39.646      4030.0
#  2026-04-13 03:20:39.646      4030.0
#  ...                             ...
#  2026-04-13 03:22:15.297     -8058.0
#  2026-04-13 03:22:15.298     -8057.0
#  2026-04-13 03:22:15.298     -8058.0
#  2026-04-13 03:22:15.298     -8058.0
#  2026-04-13 03:22:15.298     -7509.0
#
#  [647024 rows x 4 columns],
#  'n1':                           auction       price              event_time  \
#  processed_time
#  2026-04-13 03:20:39.587   3000954     56597.0 2026-04-13 03:20:35.616
#  2026-04-13 03:20:39.590   3000954      3348.0 2026-04-13 03:20:35.617
#  2026-04-13 03:20:39.591   3000954  37746798.0 2026-04-13 03:20:35.617
#  2026-04-13 03:20:39.592   3000954     96661.0 2026-04-13 03:20:35.617
#  2026-04-13 03:20:39.593   3000954      2987.0 2026-04-13 03:20:35.617
#  ...                           ...         ...                     ...
#  2026-04-13 03:22:15.300  19299561   9056742.0 2026-04-13 03:22:23.832
#  2026-04-13 03:22:15.301  13286091   1286944.0 2026-04-13 03:22:22.713
#  2026-04-13 03:22:15.301  13286091  69275802.0 2026-04-13 03:22:22.713
#  2026-04-13 03:22:15.302  28308819     76708.0 2026-04-13 03:22:24.609
#  2026-04-13 03:22:15.302  13286091    237379.0 2026-04-13 03:22:22.714
#
#                           latency_ms
#  processed_time
#  2026-04-13 03:20:39.587      3971.0
#  2026-04-13 03:20:39.590      3973.0
#  2026-04-13 03:20:39.591      3974.0
#  2026-04-13 03:20:39.592      3975.0
#  2026-04-13 03:20:39.593      3976.0
#  ...                             ...
#  2026-04-13 03:22:15.300     -8532.0
#  2026-04-13 03:22:15.301     -7412.0
#  2026-04-13 03:22:15.301     -7412.0
#  2026-04-13 03:22:15.302     -9307.0
#  2026-04-13 03:22:15.302     -7412.0
#
#  [983868 rows x 4 columns]}

# %%
# ===================== PLOTTING =====================
node_colors = {"n0": "blue", "n1": "orange"}

# ---- Latency ----
print("[PLOT] Latency...")
plt.figure()

for node, df in node_data.items():
    lat = compute_latency(df)

    plt.plot(smooth(lat["p50"]), label=f"{node} p50", color=node_colors.get(node))
    plt.plot(smooth(lat["p95"]), "--", label=f"{node} p95", color=node_colors.get(node))
    plt.plot(smooth(lat["p99"]), ":", label=f"{node} p99", color=node_colors.get(node))
# Out:
# [PLOT] Latency...

# %%
print("[PLOT] Throughput (time)...")
plt.figure()

all_failures = []

# ---- per-node + cluster aggregation ----
cluster_tp = None

for node, df in node_data.items():
    tp = compute_throughput(df)
    tp_s = smooth(tp)

    # per-node line
    plt.plot(tp_s, label=node, color=node_colors.get(node))

    # initialize cluster series
    if cluster_tp is None:
        cluster_tp = tp.copy()
    else:
        cluster_tp = cluster_tp.add(tp, fill_value=0)

    gaps = detect_failures(tp)
    for start, end in gaps:
        all_failures.append((start, end, node))

# ---- cluster throughput line ----
if cluster_tp is not None:
    cluster_tp_s = smooth(cluster_tp)
    plt.plot(cluster_tp_s, label="cluster (n0+n1)", color="black", linewidth=2)

# ---- highlight failures ----
for start, end, node in all_failures:
    plt.axvspan(start, end, alpha=0.15, color=node_colors.get(node))

plt.title(f"Throughput ({query})")
plt.xlabel("Time")
plt.ylabel("events/sec")
handles, labels = plt.gca().get_legend_handles_labels()
if labels:
    plt.legend()
else:
    print("[WARN] No data plotted → skipping legend")
plt.tight_layout()
plt.savefig(output_dir / f"throughput_{query}.png")
plt.close()
# Out:
# [PLOT] Throughput (time)...

# %%
node_data
# Out:
# {'n0':                           auction       price              event_time  \
#  processed_time
#  2026-04-13 03:20:39.597      1107      9982.0 2026-04-13 03:20:35.626
#  2026-04-13 03:20:39.617   6000924    630822.0 2026-04-13 03:20:35.616
#  2026-04-13 03:20:39.627   9001017     25308.0 2026-04-13 03:20:35.618
#  2026-04-13 03:20:39.646   6000924    248139.0 2026-04-13 03:20:35.616
#  2026-04-13 03:20:39.646  15000957      2515.0 2026-04-13 03:20:35.616
#  ...                           ...         ...                     ...
#  2026-04-13 03:22:15.297   1293837  28207884.0 2026-04-13 03:22:23.355
#  2026-04-13 03:22:15.298   1293837  10059969.0 2026-04-13 03:22:23.355
#  2026-04-13 03:22:15.298   1293837  47548803.0 2026-04-13 03:22:23.356
#  2026-04-13 03:22:15.298   1293837      1156.0 2026-04-13 03:22:23.356
#  2026-04-13 03:22:15.298  16287291    132007.0 2026-04-13 03:22:22.807
#
#                           latency_ms
#  processed_time
#  2026-04-13 03:20:39.597      3971.0
#  2026-04-13 03:20:39.617      4001.0
#  2026-04-13 03:20:39.627      4009.0
#  2026-04-13 03:20:39.646      4030.0
#  2026-04-13 03:20:39.646      4030.0
#  ...                             ...
#  2026-04-13 03:22:15.297     -8058.0
#  2026-04-13 03:22:15.298     -8057.0
#  2026-04-13 03:22:15.298     -8058.0
#  2026-04-13 03:22:15.298     -8058.0
#  2026-04-13 03:22:15.298     -7509.0
#
#  [647024 rows x 4 columns],
#  'n1':                           auction       price              event_time  \
#  processed_time
#  2026-04-13 03:20:39.587   3000954     56597.0 2026-04-13 03:20:35.616
#  2026-04-13 03:20:39.590   3000954      3348.0 2026-04-13 03:20:35.617
#  2026-04-13 03:20:39.591   3000954  37746798.0 2026-04-13 03:20:35.617
#  2026-04-13 03:20:39.592   3000954     96661.0 2026-04-13 03:20:35.617
#  2026-04-13 03:20:39.593   3000954      2987.0 2026-04-13 03:20:35.617
#  ...                           ...         ...                     ...
#  2026-04-13 03:22:15.300  19299561   9056742.0 2026-04-13 03:22:23.832
#  2026-04-13 03:22:15.301  13286091   1286944.0 2026-04-13 03:22:22.713
#  2026-04-13 03:22:15.301  13286091  69275802.0 2026-04-13 03:22:22.713
#  2026-04-13 03:22:15.302  28308819     76708.0 2026-04-13 03:22:24.609
#  2026-04-13 03:22:15.302  13286091    237379.0 2026-04-13 03:22:22.714
#
#                           latency_ms
#  processed_time
#  2026-04-13 03:20:39.587      3971.0
#  2026-04-13 03:20:39.590      3973.0
#  2026-04-13 03:20:39.591      3974.0
#  2026-04-13 03:20:39.592      3975.0
#  2026-04-13 03:20:39.593      3976.0
#  ...                             ...
#  2026-04-13 03:22:15.300     -8532.0
#  2026-04-13 03:22:15.301     -7412.0
#  2026-04-13 03:22:15.301     -7412.0
#  2026-04-13 03:22:15.302     -9307.0
#  2026-04-13 03:22:15.302     -7412.0
#
#  [983868 rows x 4 columns]}

# %%
print("[PLOT] Throughput vs cores...")
plt.figure()

core_values = [int(c.replace("p", "")) for c in cores_list]

# ---- per-node curves ----
for node, core_map in throughput_summary.items():
    y = []
    x = []

    for c in cores_list:
        if c in core_map:
            x.append(int(c.replace("p", "")))
            y.append(core_map[c])

    if len(y) > 0:
        plt.plot(x, y, marker="o", label=node)

# ---- cluster aggregation ----
cluster_curve = []

for c in cores_list:
    total = 0
    count = 0

    for node, core_map in throughput_summary.items():
        if c in core_map:
            total += core_map[c]
            count += 1

    if count > 0:
        cluster_curve.append(total)
    else:
        cluster_curve.append(None)

# clean missing points
x_clean = []
y_clean = []

for x, y in zip(core_values, cluster_curve):
    if y is not None:
        x_clean.append(x)
        y_clean.append(y)

plt.plot(x_clean, y_clean, marker="o", linewidth=3, color="black", label="cluster (n0+n1)")

plt.title(f"Throughput vs Cores ({query})")
plt.xlabel("Number of Cores")
plt.ylabel("Events/sec")
plt.grid(True, linestyle="--", alpha=0.5)
handles, labels = plt.gca().get_legend_handles_labels()
if labels:
    plt.legend()
else:
    print("[WARN] No data plotted → skipping legend")
plt.tight_layout()

plt.savefig(output_dir / f"throughput_vs_cores_{query}.png")
plt.close()
# Out:
# [PLOT] Throughput vs cores...
